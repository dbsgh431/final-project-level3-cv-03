# %%
import zipfile
import pandas as pd
import numpy as np
import re
import glob
import json
import copy
import os

from torchvision.transforms.functional import to_pil_image
import matplotlib.patches as patches
import matplotlib.pyplot as plt
from PIL import Image

# %%
images = []
annotations = []
#zip_list = sorted(glob.glob('/opt/ml/input/annotations_zip/*'))
#for i in zip_list:
#    zipfile.ZipFile(i).extractall('/opt/ml/input/annotations')

image_id = 0
ann_id = 0
json_list = sorted(glob.glob('/opt/ml/input/annotations/*'))

for zip_path in json_list:
    ann_count = 0
    with open(zip_path, 'r') as f:
        data = json.load(f)
        
    for j in  data['annotations']:
        if j['category_id'] in [3, 4, 5, 6, 7, 8]:
            ann_count += 1
            j['id'] = ann_id
            j['image_id'] = image_id
            annotations.append(j)
            ann_id += 1
        else:
            continue
    if ann_count != 0:
        data['images']['id'] = image_id
        images.append(data['images'])
        image_id += 1

# %%
images
# Out:
# [{'file_name': 'V0F_HY_0002_20210105_151454_N_CH1_Seoul_Sun_Mainroad_Day_92579.png',
#   'height': 720,
#   'width': 1280,
#   'id': 0},
#  {'file_name': 'V0F_HY_0002_20210106_151916_N_CH1_Seoul_Sun_Mainroad_Day_54036.png',
#   'height': 720,
#   'width': 1280,
#   'id': 1},
#  {'file_name': 'V0F_HY_0003_20210105_144220_N_CH1_Seoul_Sun_Mainroad_Day_07649.png',
#   'height': 720,
#   'width': 1280,
#   'id': 2},
#  {'file_name': 'V0F_HY_0004_20210106_092804_E_CH1_Seoul_Sun_Mainroad_Day_53195.png',
#   'height': 720,
#   'width': 1280,
#   'id': 3},
#  {'file_name': 'V0F_HY_0005_20210105_134517_N_CH1_Seoul_Sun_Mainroad_Day_63326.png',
#   'height': 720,
#   'width': 1280,
#   'id': 4},
#  {'file_name': 'V0F_HY_0006_20210105_155744_N_CH1_Seoul_Sun_Mainroad_Day_86810.png',
#   'height': 720,
#   'width': 1280,
#   'id': 5},
#  {'file_name': 'V0F_HY_0007_20201222_131221_E_CH1_Seoul_Sun_Mainroad_Day_85358.png',
#   'height': 720,
#   'width': 1280,
#   'id': 6},
# ...

# %%
len(annotations)
len(images)
# Out:
# 74167

# %%
images[1]
# Out:
# {'file_name': 'V0F_HY_0002_20210106_151916_N_CH1_Seoul_Sun_Mainroad_Day_54036.png',
#  'height': 720,
#  'width': 1280,
#  'id': 2}

# %%
pd.concat({i['id']: pd.DataFrame(i) for i in annotations})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 pd.concat({i['id']: pd.DataFrame(i) for i in annotations})
#
# Cell In[81], line 1, in <dictcomp>(.0)
# ----> 1 pd.concat({i['id']: pd.DataFrame(i) for i in annotations})
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:614, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     608     mgr = self._init_mgr(
#     609         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     610     )
#     612 elif isinstance(data, dict):
#     613     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615 elif isinstance(data, ma.MaskedArray):
#     616     import numpy.ma.mrecords as mrecords
#
# ...

# %%
pd.concat({k: pd.DataFrame(v) for k, v in com_icd['words'].items()}, axis=1).T

# %%
pd.DataFrame([3, 4] : {'a':1, 'b':2})
# Out:
#   Cell In[89], line 1
#     pd.DataFrame([3, 4] : {'a':1, 'b':2})
#                         ^
# SyntaxError: invalid syntax
