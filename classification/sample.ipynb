# %%
import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torch.autograd import Variable
from torch import optim
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.modules.dropout import Dropout

import time


from PIL import Image
from tqdm.auto import tqdm

import random
import numpy as np
import os
import cv2

from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt

import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

import timm

import pandas as pd
import csv

import wandb

# %%
CFG = {
    'IMG_WIDTH':540,
    'IMG_HEIGTH':960,
    'EPOCHS':50,
    'LEARNING_RATE':3e-4,
    'BATCH_SIZE':16,
    'SEED':3
}

# %%
wandb.init(
    project="Final Project", 
    entity="aitech4_cv3",
    name='effb0_sam',
    config = {
        "lr" : CFG['LEARNING_RATE'],
        "epoch" : CFG['EPOCHS'],
        "batch_size" : CFG['BATCH_SIZE'],
    }
    )

config = wandb.config
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: kdoyoon (aitech4_cv3). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.9
# Run data is saved locally in <code>/opt/ml/final-project-level3-cv-03/classification/wandb/run-20230117_145344-5m12yage</code>
# Syncing run <strong><a href="https://wandb.ai/aitech4_cv3/Final%20Project/runs/5m12yage" target="_blank">effb0_sam</a></strong> to <a href="https://wandb.ai/aitech4_cv3/Final%20Project" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#  View project at <a href="https://wandb.ai/aitech4_cv3/Final%20Project" target="_blank">https://wandb.ai/aitech4_cv3/Final%20Project</a>
#  View run at <a href="https://wandb.ai/aitech4_cv3/Final%20Project/runs/5m12yage" target="_blank">https://wandb.ai/aitech4_cv3/Final%20Project/runs/5m12yage</a>

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
data_file = pd.read_csv('/opt/ml/data/data.csv')
label = data_file['info']
data =  data_file['filepath']
X_train, y_train, X_test, y_test = train_test_split(data, label, test_size=0.2, random_state=CFG['SEED'], stratify= label)

# %%
train_transform = A.Compose([A.Resize(CFG['IMG_HEIGTH'],CFG['IMG_WIDTH']),
                             A.ToGray(p=0.5),
                             A.HorizontalFlip(p=0.3),
                            A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0),
                            ToTensorV2()
                            ])


val_transform = A.Compose([
                            A.Resize(CFG['IMG_HEIGTH'],CFG['IMG_WIDTH']),
                            A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0),
                            ToTensorV2()
                            ])



test_transform = A.Compose([
                            A.Resize(CFG['IMG_HEIGTH'],CFG['IMG_WIDTH']),
                            A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0),
                            ToTensorV2()
                            ])

# %%
X_train = X_train.reset_index()
X_test = X_test.reset_index()
y_train = y_train.reset_index()
y_test = y_test.reset_index()

# %%
class CustomDataset(Dataset):
    def __init__(self, img_paths, labels, transforms=None):
        self.img_paths = img_paths['filepath']
        self.labels = labels['info']
        self.transforms = transforms

    def __getitem__(self, index):
        img_path = self.img_paths[index]

        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        
        if self.transforms is not None:
            image = self.transforms(image=image)['image']
            
        
        if self.labels is not None:
            label = self.labels[index]
            return image, label
        else:
            return image
    
    def __len__(self):
        return len(self.img_paths)

# %%
train_dataset = CustomDataset(X_train, X_test, train_transform)
train_loader = DataLoader(train_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=True, num_workers=0)

val_dataset = CustomDataset(y_train, y_test, val_transform)
val_loader = DataLoader(val_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

# %%
class BaseModel(nn.Module):
    def __init__(self, num_classes=1):
        super(BaseModel, self).__init__()
        self.backbone = timm.create_model(model_name='efficientnet_b0', pretrained=True)
        self.backbone.classifier = nn.Linear(in_features= self.backbone.classifier.in_features, out_features=num_classes)
        
    def forward(self, x):
        x = self.backbone(x)
        x = nn.Sigmoid()(x)
        return x

# %%
def calculate_accuracy(y_pred, y):
    top_pred = torch.round(y_pred)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# %%
def validation(model, criterion, test_loader, device):
    model.eval()
    
    model_preds = []
    true_labels = []
    
    val_loss = []
    val_acc = []
    
    with torch.no_grad():
        for img, label in iter(test_loader):
            img, label = img.float().to(device), label.float().to(device).reshape(-1,1)
            
            model_pred = model(img)

            loss = criterion(model_pred, label)
            
            val_loss.append(loss.item())

            val_acc.append(calculate_accuracy(model_pred, label).item())
            
            true_labels += label.detach().cpu().numpy().tolist()

    return np.mean(val_loss), np.mean(val_acc)

# %%
def time_of_epoch(start, end):
    time_per_epoch = end - start
    time_per_epoch_min = int(time_per_epoch / 60)
    time_per_epoch_sec = int(time_per_epoch -(time_per_epoch_min*60))
    return time_per_epoch_min, time_per_epoch_sec

# %%
class SAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.05, **kwargs):
        assert rho >= 0.0, f"Invalid rho, should be non-negative: {rho}"

        defaults = dict(rho=rho, **kwargs)
        super(SAM, self).__init__(params, defaults)

        self.base_optimizer = base_optimizer(self.param_groups, **kwargs)
        self.param_groups = self.base_optimizer.param_groups

    @torch.no_grad()
    def first_step(self, zero_grad=False):
        grad_norm = self._grad_norm()
        for group in self.param_groups:
            scale = group["rho"] / (grad_norm + 1e-12)

            for p in group["params"]:
                if p.grad is None: continue
                e_w = p.grad * scale.to(p)
                p.add_(e_w)  # climb to the local maximum "w + e(w)"
                self.state[p]["e_w"] = e_w

        if zero_grad: self.zero_grad()

    @torch.no_grad()
    def second_step(self, zero_grad=False):
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None: continue
                p.sub_(self.state[p]["e_w"])  # get back to "w" from "w + e(w)"

        self.base_optimizer.step()  # do the actual "sharpness-aware" update

        if zero_grad: self.zero_grad()

    @torch.no_grad()
    def step(self, closure=None):
        assert closure is not None, "Sharpness Aware Minimization requires closure, but it was not provided"
        closure = torch.enable_grad()(closure)  # the closure should do a full forward-backward pass

        self.first_step(zero_grad=True)
        closure()
        self.second_step()

    def _grad_norm(self):
        shared_device = self.param_groups[0]["params"][0].device  # put everything on the same device, in case of model parallelism
        norm = torch.norm(
                    torch.stack([
                        p.grad.norm(p=2).to(shared_device)
                        for group in self.param_groups for p in group["params"]
                        if p.grad is not None
                    ]),
                    p=2
               )
        return norm

# %%
def train(model, optimizer, train_loader, test_loader, scheduler, device):
    model.to(device)

    criterion = nn.BCELoss().to(device)

    best_score = 0
    best_model = None

    for epoch in range(1, CFG["EPOCHS"]+1):
        model.train()
        start_time = time.monotonic()
        train_loss = []
        epoch_acc = 0
        for step,(img, label) in enumerate(train_loader): #tqdm(iter(train_loader)

            img, label = img.float().to(device), label.float().to(device)
            optimizer.zero_grad()
            label = label.view(-1,1)

            model_pred = model(img)

            acc = calculate_accuracy(model_pred, label)

            loss = criterion(model_pred, label)
            loss.backward()
            
            optimizer.first_step(zero_grad=True)
            
            criterion(model(img), label).backward()
            optimizer.second_step(zero_grad=True)
            
            train_loss.append(loss.item())

            if (step + 1) % 5 == 0:
                print(f'Epoch [{epoch}], Step [{step+1}], Train Loss : [{round(loss.item(),4):.5f}] Train acc : [{acc:.5f}]')
            wandb.log({'train_acc':acc})
        end_time = time.monotonic()
        epoch_min, epoch_sec = time_of_epoch(start_time, end_time)
        train_loss_m = np.mean(train_loss)
        epoch_acc += acc.item()
        val_loss, val_acc = validation(model, criterion, test_loader, device)

        print(f'Epoch [{epoch}], Train Loss : [{train_loss_m:.5f}] Val Loss : [{val_loss:.5f}] Val acc : [{val_acc:.5f}],Time : {epoch_min}m {epoch_sec}s')
        
        if scheduler is not None:
            scheduler.step()
         
        
        torch.save(model.state_dict(),"/opt/ml/work_dir/latest.pth")
            
        if best_score < val_acc:
            best_model = model
            best_score = val_acc
            print(f"save_best_pth EPOCH {epoch}")
            torch.save(model.state_dict(),"/opt/ml/work_dir/best.pth")
        
        wandb.log({'val_acc':val_acc})
    wandb.save("/opt/ml/work_dir/*.pth",base_path="/opt/ml/work_dir/")

    return best_model

# %%
torch.cuda.empty_cache()
model = BaseModel()
# optimizer = torch.optim.Adam(params = model.parameters(), lr = CFG["LEARNING_RATE"])
optimizer = SAM(model.parameters(), torch.optim.SGD , lr=CFG["LEARNING_RATE"], momentum=0.9)
scheduler = None
infer_model = train(model, optimizer, train_loader, val_loader, scheduler, device)
# Out:
# Epoch [1], Step [5], Train Loss : [0.67190] Train acc : [0.62500]
# Epoch [1], Step [10], Train Loss : [0.73890] Train acc : [0.37500]
# Epoch [1], Step [15], Train Loss : [0.73860] Train acc : [0.43750]
# Epoch [1], Step [20], Train Loss : [0.66490] Train acc : [0.62500]
# Epoch [1], Step [25], Train Loss : [0.67020] Train acc : [0.68750]
# Epoch [1], Step [30], Train Loss : [0.64730] Train acc : [0.81250]
# Epoch [1], Step [35], Train Loss : [0.70190] Train acc : [0.50000]
# Epoch [1], Step [40], Train Loss : [0.67670] Train acc : [0.56250]
# Epoch [1], Step [45], Train Loss : [0.68820] Train acc : [0.68750]
# Epoch [1], Step [50], Train Loss : [0.68740] Train acc : [0.43750]
# Epoch [1], Step [55], Train Loss : [0.69100] Train acc : [0.50000]
# Epoch [1], Step [60], Train Loss : [0.67740] Train acc : [0.75000]
# Epoch [1], Step [65], Train Loss : [0.67390] Train acc : [0.75000]
# Epoch [1], Step [70], Train Loss : [0.65040] Train acc : [0.81250]
# Epoch [1], Step [75], Train Loss : [0.67320] Train acc : [0.62500]
# Epoch [1], Step [80], Train Loss : [0.65200] Train acc : [0.81250]
# Epoch [1], Step [85], Train Loss : [0.65660] Train acc : [0.68750]
# Epoch [1], Train Loss : [0.67886] Val Loss : [0.65889] Val acc : [0.68068],Time : 1m 35s
# save_best_pth EPOCH 1
# Epoch [2], Step [5], Train Loss : [0.66590] Train acc : [0.62500]
# Epoch [2], Step [10], Train Loss : [0.65700] Train acc : [0.75000]
# Epoch [2], Step [15], Train Loss : [0.66250] Train acc : [0.62500]
# Epoch [2], Step [20], Train Loss : [0.66930] Train acc : [0.62500]
# Epoch [2], Step [25], Train Loss : [0.64970] Train acc : [0.68750]
# Epoch [2], Step [30], Train Loss : [0.62580] Train acc : [0.75000]
# Epoch [2], Step [35], Train Loss : [0.64400] Train acc : [0.68750]
# Epoch [2], Step [40], Train Loss : [0.62370] Train acc : [0.75000]
# Epoch [2], Step [45], Train Loss : [0.64930] Train acc : [0.62500]
# Epoch [2], Step [50], Train Loss : [0.62670] Train acc : [0.93750]
# Epoch [2], Step [55], Train Loss : [0.64680] Train acc : [0.56250]
# Epoch [2], Step [60], Train Loss : [0.64760] Train acc : [0.62500]
# Epoch [2], Step [65], Train Loss : [0.63540] Train acc : [0.62500]
# Epoch [2], Step [70], Train Loss : [0.62100] Train acc : [0.75000]
# Epoch [2], Step [75], Train Loss : [0.65070] Train acc : [0.75000]
# Epoch [2], Step [80], Train Loss : [0.66760] Train acc : [0.43750]
# Epoch [2], Step [85], Train Loss : [0.64380] Train acc : [0.81250]
# Epoch [2], Train Loss : [0.64273] Val Loss : [0.62771] Val acc : [0.70341],Time : 1m 35s
# save_best_pth EPOCH 2
# Epoch [3], Step [5], Train Loss : [0.64210] Train acc : [0.56250]
# Epoch [3], Step [10], Train Loss : [0.61340] Train acc : [0.87500]
# Epoch [3], Step [15], Train Loss : [0.58560] Train acc : [0.81250]
# Epoch [3], Step [20], Train Loss : [0.60830] Train acc : [0.81250]
# Epoch [3], Step [25], Train Loss : [0.64140] Train acc : [0.50000]
# Epoch [3], Step [30], Train Loss : [0.66880] Train acc : [0.56250]
# Epoch [3], Step [35], Train Loss : [0.64010] Train acc : [0.81250]
# Epoch [3], Step [40], Train Loss : [0.62320] Train acc : [0.81250]
# Epoch [3], Step [45], Train Loss : [0.63190] Train acc : [0.68750]
# Epoch [3], Step [50], Train Loss : [0.71390] Train acc : [0.56250]
# Epoch [3], Step [55], Train Loss : [0.60730] Train acc : [0.75000]
# Epoch [3], Step [60], Train Loss : [0.62020] Train acc : [0.68750]
# Epoch [3], Step [65], Train Loss : [0.58530] Train acc : [0.75000]
# Epoch [3], Step [70], Train Loss : [0.61870] Train acc : [0.62500]
# Epoch [3], Step [75], Train Loss : [0.62670] Train acc : [0.75000]
# Epoch [3], Step [80], Train Loss : [0.57580] Train acc : [0.68750]
# Epoch [3], Step [85], Train Loss : [0.57110] Train acc : [0.87500]
# Epoch [3], Train Loss : [0.61505] Val Loss : [0.59993] Val acc : [0.72045],Time : 1m 36s
# save_best_pth EPOCH 3
# Epoch [4], Step [5], Train Loss : [0.59200] Train acc : [0.68750]
# Epoch [4], Step [10], Train Loss : [0.55970] Train acc : [0.93750]
# Epoch [4], Step [15], Train Loss : [0.60400] Train acc : [0.68750]
# Epoch [4], Step [20], Train Loss : [0.67100] Train acc : [0.68750]
# Epoch [4], Step [25], Train Loss : [0.67170] Train acc : [0.56250]
# Epoch [4], Step [30], Train Loss : [0.64260] Train acc : [0.62500]
# Epoch [4], Step [35], Train Loss : [0.60210] Train acc : [0.62500]
# Epoch [4], Step [40], Train Loss : [0.58280] Train acc : [0.87500]
# Epoch [4], Step [45], Train Loss : [0.59270] Train acc : [0.75000]
# Epoch [4], Step [50], Train Loss : [0.60960] Train acc : [0.68750]
# Epoch [4], Step [55], Train Loss : [0.63350] Train acc : [0.68750]
# Epoch [4], Step [60], Train Loss : [0.60810] Train acc : [0.62500]
# Epoch [4], Step [65], Train Loss : [0.55190] Train acc : [0.87500]
# Epoch [4], Step [70], Train Loss : [0.50360] Train acc : [0.87500]
# Epoch [4], Step [75], Train Loss : [0.45580] Train acc : [1.00000]
# Epoch [4], Step [80], Train Loss : [0.54250] Train acc : [0.93750]
# Epoch [4], Step [85], Train Loss : [0.56900] Train acc : [0.68750]
# Epoch [4], Train Loss : [0.59333] Val Loss : [0.58038] Val acc : [0.72330],Time : 1m 36s
# save_best_pth EPOCH 4
# Epoch [5], Step [5], Train Loss : [0.62050] Train acc : [0.68750]
# Epoch [5], Step [10], Train Loss : [0.62850] Train acc : [0.62500]
# Epoch [5], Step [15], Train Loss : [0.55260] Train acc : [0.87500]
# Epoch [5], Step [20], Train Loss : [0.47610] Train acc : [0.93750]
# Epoch [5], Step [25], Train Loss : [0.62750] Train acc : [0.62500]
# Epoch [5], Step [30], Train Loss : [0.53960] Train acc : [0.68750]
# Epoch [5], Step [35], Train Loss : [0.56720] Train acc : [0.87500]
# Epoch [5], Step [40], Train Loss : [0.59950] Train acc : [0.56250]
# Epoch [5], Step [45], Train Loss : [0.59520] Train acc : [0.75000]
# Epoch [5], Step [50], Train Loss : [0.57160] Train acc : [0.81250]
# Epoch [5], Step [55], Train Loss : [0.59430] Train acc : [0.75000]
# Epoch [5], Step [60], Train Loss : [0.49470] Train acc : [0.87500]
# Epoch [5], Step [65], Train Loss : [0.52970] Train acc : [0.68750]
# Epoch [5], Step [70], Train Loss : [0.60130] Train acc : [0.68750]
# Epoch [5], Step [75], Train Loss : [0.55290] Train acc : [0.75000]
# Epoch [5], Step [80], Train Loss : [0.59430] Train acc : [0.81250]
# Epoch [5], Step [85], Train Loss : [0.55430] Train acc : [0.75000]
# Epoch [5], Train Loss : [0.56943] Val Loss : [0.55670] Val acc : [0.74091],Time : 1m 36s
# save_best_pth EPOCH 5
# Epoch [6], Step [5], Train Loss : [0.56420] Train acc : [0.75000]
# Epoch [6], Step [10], Train Loss : [0.45610] Train acc : [0.81250]
# Epoch [6], Step [15], Train Loss : [0.51240] Train acc : [0.81250]
# Epoch [6], Step [20], Train Loss : [0.48250] Train acc : [0.81250]
# Epoch [6], Step [25], Train Loss : [0.64480] Train acc : [0.68750]
# Epoch [6], Step [30], Train Loss : [0.55140] Train acc : [0.68750]
# Epoch [6], Step [35], Train Loss : [0.52750] Train acc : [0.87500]
# Epoch [6], Step [40], Train Loss : [0.51520] Train acc : [0.81250]
# Epoch [6], Step [45], Train Loss : [0.61230] Train acc : [0.68750]
# Epoch [6], Step [50], Train Loss : [0.63670] Train acc : [0.62500]
# Epoch [6], Step [55], Train Loss : [0.59420] Train acc : [0.68750]
# Epoch [6], Step [60], Train Loss : [0.60980] Train acc : [0.62500]
# Epoch [6], Step [65], Train Loss : [0.51740] Train acc : [0.75000]
# Epoch [6], Step [70], Train Loss : [0.63080] Train acc : [0.56250]
# Epoch [6], Step [75], Train Loss : [0.64990] Train acc : [0.50000]
# Epoch [6], Step [80], Train Loss : [0.45560] Train acc : [0.87500]
# Epoch [6], Step [85], Train Loss : [0.44080] Train acc : [0.81250]
# Epoch [6], Train Loss : [0.55519] Val Loss : [0.54469] Val acc : [0.74886],Time : 1m 36s
# save_best_pth EPOCH 6
# Epoch [7], Step [5], Train Loss : [0.55400] Train acc : [0.68750]
# Epoch [7], Step [10], Train Loss : [0.55190] Train acc : [0.81250]
# Epoch [7], Step [15], Train Loss : [0.50010] Train acc : [0.87500]
# Epoch [7], Step [20], Train Loss : [0.56070] Train acc : [0.75000]
# Epoch [7], Step [25], Train Loss : [0.68490] Train acc : [0.62500]
# Epoch [7], Step [30], Train Loss : [0.57980] Train acc : [0.75000]
# Epoch [7], Step [35], Train Loss : [0.55760] Train acc : [0.75000]
# Epoch [7], Step [40], Train Loss : [0.50130] Train acc : [0.81250]
# Epoch [7], Step [45], Train Loss : [0.57490] Train acc : [0.75000]
# Epoch [7], Step [50], Train Loss : [0.50250] Train acc : [0.81250]
# Epoch [7], Step [55], Train Loss : [0.63590] Train acc : [0.62500]
# Epoch [7], Step [60], Train Loss : [0.49630] Train acc : [0.81250]
# Epoch [7], Step [65], Train Loss : [0.52650] Train acc : [0.75000]
# Epoch [7], Step [70], Train Loss : [0.49590] Train acc : [0.62500]
# Epoch [7], Step [75], Train Loss : [0.60990] Train acc : [0.56250]
# Epoch [7], Step [80], Train Loss : [0.58250] Train acc : [0.68750]
# Epoch [7], Step [85], Train Loss : [0.42390] Train acc : [0.93750]
# Epoch [7], Train Loss : [0.53850] Val Loss : [0.52953] Val acc : [0.75511],Time : 1m 36s
# save_best_pth EPOCH 7
# Epoch [8], Step [5], Train Loss : [0.44370] Train acc : [0.81250]
# Epoch [8], Step [10], Train Loss : [0.39180] Train acc : [0.93750]
# Epoch [8], Step [15], Train Loss : [0.61260] Train acc : [0.75000]
# Epoch [8], Step [20], Train Loss : [0.46630] Train acc : [0.75000]
# Epoch [8], Step [25], Train Loss : [0.50790] Train acc : [0.68750]
# Epoch [8], Step [30], Train Loss : [0.50820] Train acc : [0.81250]
# Epoch [8], Step [35], Train Loss : [0.43580] Train acc : [0.87500]
# Epoch [8], Step [40], Train Loss : [0.58280] Train acc : [0.68750]
# Epoch [8], Step [45], Train Loss : [0.57900] Train acc : [0.68750]
# Epoch [8], Step [50], Train Loss : [0.47800] Train acc : [0.75000]
# Epoch [8], Step [55], Train Loss : [0.47420] Train acc : [0.87500]
# Epoch [8], Step [60], Train Loss : [0.48700] Train acc : [0.81250]
# Epoch [8], Step [65], Train Loss : [0.54860] Train acc : [0.75000]
# Epoch [8], Step [70], Train Loss : [0.42850] Train acc : [0.87500]
# Epoch [8], Step [75], Train Loss : [0.61040] Train acc : [0.62500]
# Epoch [8], Step [80], Train Loss : [0.46280] Train acc : [0.81250]
# Epoch [8], Step [85], Train Loss : [0.63750] Train acc : [0.68750]
# Epoch [8], Train Loss : [0.52250] Val Loss : [0.51016] Val acc : [0.76648],Time : 1m 35s
# save_best_pth EPOCH 8
# Epoch [9], Step [5], Train Loss : [0.53980] Train acc : [0.81250]
# Epoch [9], Step [10], Train Loss : [0.50310] Train acc : [0.81250]
# Epoch [9], Step [15], Train Loss : [0.56600] Train acc : [0.62500]
# Epoch [9], Step [20], Train Loss : [0.50660] Train acc : [0.81250]
# Epoch [9], Step [25], Train Loss : [0.50180] Train acc : [0.75000]
# Epoch [9], Step [30], Train Loss : [0.46790] Train acc : [0.87500]
# Epoch [9], Step [35], Train Loss : [0.43330] Train acc : [0.81250]
# Epoch [9], Step [40], Train Loss : [0.57840] Train acc : [0.68750]
# Epoch [9], Step [45], Train Loss : [0.47480] Train acc : [0.87500]
# Epoch [9], Step [50], Train Loss : [0.41050] Train acc : [0.87500]
# Epoch [9], Step [55], Train Loss : [0.54210] Train acc : [0.68750]
# Epoch [9], Step [60], Train Loss : [0.54400] Train acc : [0.68750]
# Epoch [9], Step [65], Train Loss : [0.51830] Train acc : [0.75000]
# Epoch [9], Step [70], Train Loss : [0.47180] Train acc : [0.75000]
# Epoch [9], Step [75], Train Loss : [0.41600] Train acc : [0.93750]
# Epoch [9], Step [80], Train Loss : [0.53110] Train acc : [0.75000]
# Epoch [9], Step [85], Train Loss : [0.46040] Train acc : [0.75000]
# Epoch [9], Train Loss : [0.51055] Val Loss : [0.50229] Val acc : [0.75227],Time : 1m 35s
# Epoch [10], Step [5], Train Loss : [0.56370] Train acc : [0.56250]
# Epoch [10], Step [10], Train Loss : [0.52260] Train acc : [0.68750]
# Epoch [10], Step [15], Train Loss : [0.57840] Train acc : [0.68750]
# Epoch [10], Step [20], Train Loss : [0.40020] Train acc : [0.81250]
# Epoch [10], Step [25], Train Loss : [0.54410] Train acc : [0.75000]
# Epoch [10], Step [30], Train Loss : [0.45400] Train acc : [0.81250]
# Epoch [10], Step [35], Train Loss : [0.45830] Train acc : [0.75000]
# Epoch [10], Step [40], Train Loss : [0.44820] Train acc : [0.87500]
# Epoch [10], Step [45], Train Loss : [0.60060] Train acc : [0.56250]
# Epoch [10], Step [50], Train Loss : [0.51180] Train acc : [0.62500]
# Epoch [10], Step [55], Train Loss : [0.51090] Train acc : [0.81250]
# Epoch [10], Step [60], Train Loss : [0.41970] Train acc : [0.87500]
# Epoch [10], Step [65], Train Loss : [0.34070] Train acc : [0.93750]
# Epoch [10], Step [70], Train Loss : [0.45180] Train acc : [0.75000]
# Epoch [10], Step [75], Train Loss : [0.60030] Train acc : [0.56250]
# Epoch [10], Step [80], Train Loss : [0.59370] Train acc : [0.68750]
# Epoch [10], Step [85], Train Loss : [0.42080] Train acc : [0.75000]
# Epoch [10], Train Loss : [0.49795] Val Loss : [0.49133] Val acc : [0.78352],Time : 1m 35s
# save_best_pth EPOCH 10
# Epoch [11], Step [5], Train Loss : [0.46330] Train acc : [0.87500]
# Epoch [11], Step [10], Train Loss : [0.39800] Train acc : [0.81250]
# Epoch [11], Step [15], Train Loss : [0.49240] Train acc : [0.68750]
# Epoch [11], Step [20], Train Loss : [0.53480] Train acc : [0.81250]
# Epoch [11], Step [25], Train Loss : [0.40600] Train acc : [0.87500]
# Epoch [11], Step [30], Train Loss : [0.46050] Train acc : [0.87500]
# Epoch [11], Step [35], Train Loss : [0.56410] Train acc : [0.68750]
# Epoch [11], Step [40], Train Loss : [0.47880] Train acc : [0.68750]
# Epoch [11], Step [45], Train Loss : [0.51500] Train acc : [0.75000]
# Epoch [11], Step [50], Train Loss : [0.41570] Train acc : [0.75000]
# Epoch [11], Step [55], Train Loss : [0.51190] Train acc : [0.75000]
# Epoch [11], Step [60], Train Loss : [0.54030] Train acc : [0.75000]
# Epoch [11], Step [65], Train Loss : [0.42790] Train acc : [0.81250]
# Epoch [11], Step [70], Train Loss : [0.67440] Train acc : [0.62500]
# Epoch [11], Step [75], Train Loss : [0.53380] Train acc : [0.75000]
# Epoch [11], Step [80], Train Loss : [0.44740] Train acc : [0.75000]
# Epoch [11], Step [85], Train Loss : [0.36380] Train acc : [0.93750]
# Epoch [11], Train Loss : [0.48216] Val Loss : [0.48841] Val acc : [0.78011],Time : 1m 37s
# Epoch [12], Step [5], Train Loss : [0.34670] Train acc : [0.93750]
# Epoch [12], Step [10], Train Loss : [0.41200] Train acc : [0.81250]
# Epoch [12], Step [15], Train Loss : [0.37020] Train acc : [0.81250]
# Epoch [12], Step [20], Train Loss : [0.51940] Train acc : [0.68750]
# Epoch [12], Step [25], Train Loss : [0.39260] Train acc : [0.81250]
# Epoch [12], Step [30], Train Loss : [0.40740] Train acc : [0.75000]
# Epoch [12], Step [35], Train Loss : [0.60490] Train acc : [0.62500]
# Epoch [12], Step [40], Train Loss : [0.39070] Train acc : [0.87500]
# Epoch [12], Step [45], Train Loss : [0.52680] Train acc : [0.75000]
# Epoch [12], Step [50], Train Loss : [0.45250] Train acc : [0.75000]
# Epoch [12], Step [55], Train Loss : [0.51770] Train acc : [0.81250]
# Epoch [12], Step [60], Train Loss : [0.44320] Train acc : [0.87500]
# Epoch [12], Step [65], Train Loss : [0.58440] Train acc : [0.62500]
# Epoch [12], Step [70], Train Loss : [0.64440] Train acc : [0.56250]
# Epoch [12], Step [75], Train Loss : [0.37340] Train acc : [0.81250]
# Epoch [12], Step [80], Train Loss : [0.49520] Train acc : [0.87500]
# Epoch [12], Step [85], Train Loss : [0.55370] Train acc : [0.68750]
# Epoch [12], Train Loss : [0.46981] Val Loss : [0.47701] Val acc : [0.79148],Time : 1m 35s
# save_best_pth EPOCH 12
# Epoch [13], Step [5], Train Loss : [0.40160] Train acc : [0.87500]
# Epoch [13], Step [10], Train Loss : [0.33490] Train acc : [0.93750]
# Epoch [13], Step [15], Train Loss : [0.66280] Train acc : [0.56250]
# Epoch [13], Step [20], Train Loss : [0.36350] Train acc : [0.87500]
# Epoch [13], Step [25], Train Loss : [0.49290] Train acc : [0.68750]
# Epoch [13], Step [30], Train Loss : [0.48640] Train acc : [0.75000]
# Epoch [13], Step [35], Train Loss : [0.42480] Train acc : [0.75000]
# Epoch [13], Step [40], Train Loss : [0.35860] Train acc : [0.87500]
# Epoch [13], Step [45], Train Loss : [0.42860] Train acc : [0.81250]
# Epoch [13], Step [50], Train Loss : [0.42700] Train acc : [0.75000]
# Epoch [13], Step [55], Train Loss : [0.56020] Train acc : [0.81250]
# Epoch [13], Step [60], Train Loss : [0.48320] Train acc : [0.75000]
# Epoch [13], Step [65], Train Loss : [0.39500] Train acc : [0.93750]
# Epoch [13], Step [70], Train Loss : [0.39160] Train acc : [0.75000]
# Epoch [13], Step [75], Train Loss : [0.54610] Train acc : [0.75000]
# Epoch [13], Step [80], Train Loss : [0.37050] Train acc : [0.87500]
# Epoch [13], Step [85], Train Loss : [0.47570] Train acc : [0.68750]
# Epoch [13], Train Loss : [0.45031] Val Loss : [0.45697] Val acc : [0.80341],Time : 1m 36s
# save_best_pth EPOCH 13
# Epoch [14], Step [5], Train Loss : [0.37400] Train acc : [0.93750]
# Epoch [14], Step [10], Train Loss : [0.39580] Train acc : [0.81250]
# Epoch [14], Step [15], Train Loss : [0.46520] Train acc : [0.81250]
# Epoch [14], Step [20], Train Loss : [0.36240] Train acc : [0.87500]
# Epoch [14], Step [25], Train Loss : [0.47980] Train acc : [0.68750]
# Epoch [14], Step [30], Train Loss : [0.37790] Train acc : [0.87500]
# Epoch [14], Step [35], Train Loss : [0.60670] Train acc : [0.68750]
# Epoch [14], Step [40], Train Loss : [0.56060] Train acc : [0.75000]
# Epoch [14], Step [45], Train Loss : [0.50610] Train acc : [0.68750]
# Epoch [14], Step [50], Train Loss : [0.34260] Train acc : [0.93750]
# Epoch [14], Step [55], Train Loss : [0.35430] Train acc : [0.81250]
# Epoch [14], Step [60], Train Loss : [0.48200] Train acc : [0.68750]
# Epoch [14], Step [65], Train Loss : [0.38360] Train acc : [0.81250]
# Epoch [14], Step [70], Train Loss : [0.35180] Train acc : [1.00000]
# Epoch [14], Step [75], Train Loss : [0.45040] Train acc : [0.68750]
# Epoch [14], Step [80], Train Loss : [0.38060] Train acc : [0.87500]
# Epoch [14], Step [85], Train Loss : [0.54880] Train acc : [0.75000]
# Epoch [14], Train Loss : [0.45559] Val Loss : [0.45176] Val acc : [0.78352],Time : 1m 35s
# Epoch [15], Step [5], Train Loss : [0.53500] Train acc : [0.75000]
# Epoch [15], Step [10], Train Loss : [0.42390] Train acc : [0.87500]
# Epoch [15], Step [15], Train Loss : [0.42710] Train acc : [0.87500]
# Epoch [15], Step [20], Train Loss : [0.45510] Train acc : [0.75000]
# Epoch [15], Step [25], Train Loss : [0.36760] Train acc : [0.87500]
# Epoch [15], Step [30], Train Loss : [0.37090] Train acc : [0.75000]
# Epoch [15], Step [35], Train Loss : [0.36760] Train acc : [0.93750]
# Epoch [15], Step [40], Train Loss : [0.61090] Train acc : [0.68750]
# Epoch [15], Step [45], Train Loss : [0.47830] Train acc : [0.75000]
# Epoch [15], Step [50], Train Loss : [0.39880] Train acc : [0.87500]
# Epoch [15], Step [55], Train Loss : [0.48620] Train acc : [0.75000]
# Epoch [15], Step [60], Train Loss : [0.67210] Train acc : [0.56250]
# Epoch [15], Step [65], Train Loss : [0.39520] Train acc : [0.87500]
# Epoch [15], Step [70], Train Loss : [0.55380] Train acc : [0.68750]
# Epoch [15], Step [75], Train Loss : [0.39160] Train acc : [0.75000]
# Epoch [15], Step [80], Train Loss : [0.61640] Train acc : [0.68750]
# Epoch [15], Step [85], Train Loss : [0.51050] Train acc : [0.75000]
# Epoch [15], Train Loss : [0.44041] Val Loss : [0.44348] Val acc : [0.81193],Time : 1m 35s
# save_best_pth EPOCH 15
# Epoch [16], Step [5], Train Loss : [0.47270] Train acc : [0.75000]
# Epoch [16], Step [10], Train Loss : [0.44990] Train acc : [0.81250]
# Epoch [16], Step [15], Train Loss : [0.42410] Train acc : [0.81250]
# Epoch [16], Step [20], Train Loss : [0.49930] Train acc : [0.62500]
# Epoch [16], Step [25], Train Loss : [0.67080] Train acc : [0.75000]
# Epoch [16], Step [30], Train Loss : [0.37460] Train acc : [0.81250]
# Epoch [16], Step [35], Train Loss : [0.44680] Train acc : [0.81250]
# Epoch [16], Step [40], Train Loss : [0.42310] Train acc : [0.93750]
# Epoch [16], Step [45], Train Loss : [0.38230] Train acc : [0.93750]
# Epoch [16], Step [50], Train Loss : [0.60950] Train acc : [0.62500]
# Epoch [16], Step [55], Train Loss : [0.56090] Train acc : [0.68750]
# Epoch [16], Step [60], Train Loss : [0.37570] Train acc : [0.93750]
# Epoch [16], Step [65], Train Loss : [0.44440] Train acc : [0.75000]
# Epoch [16], Step [70], Train Loss : [0.54110] Train acc : [0.87500]
# Epoch [16], Step [75], Train Loss : [0.38390] Train acc : [0.87500]
# Epoch [16], Step [80], Train Loss : [0.46120] Train acc : [0.68750]
# Epoch [16], Step [85], Train Loss : [0.72630] Train acc : [0.62500]
# Epoch [16], Train Loss : [0.43232] Val Loss : [0.43292] Val acc : [0.79489],Time : 1m 36s
# Epoch [17], Step [5], Train Loss : [0.49590] Train acc : [0.68750]
# Epoch [17], Step [10], Train Loss : [0.48180] Train acc : [0.81250]
# Epoch [17], Step [15], Train Loss : [0.37880] Train acc : [0.87500]
# Epoch [17], Step [20], Train Loss : [0.34790] Train acc : [0.87500]
# Epoch [17], Step [25], Train Loss : [0.41350] Train acc : [0.81250]
# Epoch [17], Step [30], Train Loss : [0.39020] Train acc : [0.93750]
# Epoch [17], Step [35], Train Loss : [0.59490] Train acc : [0.75000]
# Epoch [17], Step [40], Train Loss : [0.29160] Train acc : [1.00000]
# Epoch [17], Step [45], Train Loss : [0.37240] Train acc : [0.93750]
# Epoch [17], Step [50], Train Loss : [0.59290] Train acc : [0.68750]
# Epoch [17], Step [55], Train Loss : [0.36180] Train acc : [0.93750]
# Epoch [17], Step [60], Train Loss : [0.23970] Train acc : [1.00000]
# Epoch [17], Step [65], Train Loss : [0.36560] Train acc : [0.93750]
# Epoch [17], Step [70], Train Loss : [0.36500] Train acc : [0.93750]
# Epoch [17], Step [75], Train Loss : [0.43400] Train acc : [0.87500]
# Epoch [17], Step [80], Train Loss : [0.39980] Train acc : [0.87500]
# Epoch [17], Step [85], Train Loss : [0.46600] Train acc : [0.81250]
# Epoch [17], Train Loss : [0.42295] Val Loss : [0.42936] Val acc : [0.80909],Time : 1m 36s
# Epoch [18], Step [5], Train Loss : [0.35450] Train acc : [0.93750]
# Epoch [18], Step [10], Train Loss : [0.80010] Train acc : [0.50000]
# Epoch [18], Step [15], Train Loss : [0.49650] Train acc : [0.75000]
# Epoch [18], Step [20], Train Loss : [0.71220] Train acc : [0.68750]
# Epoch [18], Step [25], Train Loss : [0.45310] Train acc : [0.93750]
# Epoch [18], Step [30], Train Loss : [0.43970] Train acc : [0.87500]
# Epoch [18], Step [35], Train Loss : [0.26970] Train acc : [0.93750]
# Epoch [18], Step [40], Train Loss : [0.32700] Train acc : [0.93750]
# Epoch [18], Step [45], Train Loss : [0.68610] Train acc : [0.56250]
# Epoch [18], Step [50], Train Loss : [0.37210] Train acc : [0.93750]
# Epoch [18], Step [55], Train Loss : [0.56650] Train acc : [0.68750]
# Epoch [18], Step [60], Train Loss : [0.35740] Train acc : [0.81250]
# Epoch [18], Step [65], Train Loss : [0.49350] Train acc : [0.81250]
# Epoch [18], Step [70], Train Loss : [0.41260] Train acc : [0.75000]
# Epoch [18], Step [75], Train Loss : [0.49230] Train acc : [0.81250]
# Epoch [18], Step [80], Train Loss : [0.41470] Train acc : [0.87500]
# Epoch [18], Step [85], Train Loss : [0.36310] Train acc : [0.87500]
# Epoch [18], Train Loss : [0.41274] Val Loss : [0.42186] Val acc : [0.80057],Time : 1m 36s
# Epoch [19], Step [5], Train Loss : [0.40530] Train acc : [0.81250]
# Epoch [19], Step [10], Train Loss : [0.35320] Train acc : [0.81250]
# Epoch [19], Step [15], Train Loss : [0.44400] Train acc : [0.81250]
# Epoch [19], Step [20], Train Loss : [0.33690] Train acc : [0.93750]
# Epoch [19], Step [25], Train Loss : [0.30680] Train acc : [0.93750]
# Epoch [19], Step [30], Train Loss : [0.44060] Train acc : [0.81250]
# Epoch [19], Step [35], Train Loss : [0.53810] Train acc : [0.75000]
# Epoch [19], Step [40], Train Loss : [0.46660] Train acc : [0.81250]
# Epoch [19], Step [45], Train Loss : [0.35370] Train acc : [0.87500]
# Epoch [19], Step [50], Train Loss : [0.35210] Train acc : [0.87500]
# Epoch [19], Step [55], Train Loss : [0.47190] Train acc : [0.75000]
# Epoch [19], Step [60], Train Loss : [0.37690] Train acc : [0.87500]
# Epoch [19], Step [65], Train Loss : [0.49180] Train acc : [0.81250]
# Epoch [19], Step [70], Train Loss : [0.44060] Train acc : [0.81250]
# Epoch [19], Step [75], Train Loss : [0.40350] Train acc : [0.81250]
# Epoch [19], Step [80], Train Loss : [0.35830] Train acc : [0.87500]
# Epoch [19], Step [85], Train Loss : [0.43030] Train acc : [0.68750]
# Epoch [19], Train Loss : [0.39839] Val Loss : [0.42290] Val acc : [0.80909],Time : 1m 35s
# Epoch [20], Step [5], Train Loss : [0.36970] Train acc : [0.81250]
# Epoch [20], Step [10], Train Loss : [0.31990] Train acc : [0.81250]
# Epoch [20], Step [15], Train Loss : [0.37750] Train acc : [0.81250]
# Epoch [20], Step [20], Train Loss : [0.27160] Train acc : [0.87500]
# Epoch [20], Step [25], Train Loss : [0.33780] Train acc : [0.75000]
# Epoch [20], Step [30], Train Loss : [0.43330] Train acc : [0.75000]
# Epoch [20], Step [35], Train Loss : [0.43260] Train acc : [0.68750]
# Epoch [20], Step [40], Train Loss : [0.48570] Train acc : [0.75000]
# Epoch [20], Step [45], Train Loss : [0.39990] Train acc : [0.93750]
# Epoch [20], Step [50], Train Loss : [0.29560] Train acc : [0.87500]
# Epoch [20], Step [55], Train Loss : [0.62480] Train acc : [0.68750]
# Epoch [20], Step [60], Train Loss : [0.35770] Train acc : [0.87500]
# Epoch [20], Step [65], Train Loss : [0.42330] Train acc : [0.81250]
# Epoch [20], Step [70], Train Loss : [0.48810] Train acc : [0.68750]
# Epoch [20], Step [75], Train Loss : [0.49810] Train acc : [0.75000]
# Epoch [20], Step [80], Train Loss : [0.26280] Train acc : [0.93750]
# Epoch [20], Step [85], Train Loss : [0.35820] Train acc : [0.87500]
# Epoch [20], Train Loss : [0.38780] Val Loss : [0.40838] Val acc : [0.81193],Time : 1m 35s
# Epoch [21], Step [5], Train Loss : [0.35740] Train acc : [0.81250]
# Epoch [21], Step [10], Train Loss : [0.29100] Train acc : [0.87500]
# Epoch [21], Step [15], Train Loss : [0.51590] Train acc : [0.81250]
# Epoch [21], Step [20], Train Loss : [0.35550] Train acc : [0.87500]
# Epoch [21], Step [25], Train Loss : [0.28550] Train acc : [0.93750]
# Epoch [21], Step [30], Train Loss : [0.39390] Train acc : [0.81250]
# Epoch [21], Step [35], Train Loss : [0.41240] Train acc : [0.81250]
# Epoch [21], Step [40], Train Loss : [0.25950] Train acc : [0.93750]
# Epoch [21], Step [45], Train Loss : [0.54760] Train acc : [0.81250]
# Epoch [21], Step [50], Train Loss : [0.30680] Train acc : [0.93750]
# Epoch [21], Step [55], Train Loss : [0.36540] Train acc : [0.87500]
# Epoch [21], Step [60], Train Loss : [0.33860] Train acc : [0.87500]
# Epoch [21], Step [65], Train Loss : [0.46070] Train acc : [0.81250]
# Epoch [21], Step [70], Train Loss : [0.42810] Train acc : [0.81250]
# Epoch [21], Step [75], Train Loss : [0.48980] Train acc : [0.81250]
# Epoch [21], Step [80], Train Loss : [0.39700] Train acc : [0.81250]
# Epoch [21], Step [85], Train Loss : [0.41920] Train acc : [0.87500]
# Epoch [21], Train Loss : [0.39099] Val Loss : [0.40476] Val acc : [0.82330],Time : 1m 35s
# save_best_pth EPOCH 21
# Epoch [22], Step [5], Train Loss : [0.45400] Train acc : [0.81250]
# Epoch [22], Step [10], Train Loss : [0.48040] Train acc : [0.68750]
# Epoch [22], Step [15], Train Loss : [0.24760] Train acc : [0.93750]
# Epoch [22], Step [20], Train Loss : [0.51290] Train acc : [0.81250]
# Epoch [22], Step [25], Train Loss : [0.29670] Train acc : [0.93750]
# Epoch [22], Step [30], Train Loss : [0.25250] Train acc : [0.93750]
# Epoch [22], Step [35], Train Loss : [0.30800] Train acc : [0.87500]
# Epoch [22], Step [40], Train Loss : [0.52160] Train acc : [0.62500]
# Epoch [22], Step [45], Train Loss : [0.40190] Train acc : [0.68750]
# Epoch [22], Step [50], Train Loss : [0.43310] Train acc : [0.75000]
# Epoch [22], Step [55], Train Loss : [0.33080] Train acc : [0.87500]
# Epoch [22], Step [60], Train Loss : [0.30240] Train acc : [0.93750]
# Epoch [22], Step [65], Train Loss : [0.30230] Train acc : [0.87500]
# Epoch [22], Step [70], Train Loss : [0.75150] Train acc : [0.75000]
# Epoch [22], Step [75], Train Loss : [0.40710] Train acc : [0.81250]
# Epoch [22], Step [80], Train Loss : [0.53520] Train acc : [0.75000]
# Epoch [22], Step [85], Train Loss : [0.26780] Train acc : [1.00000]
# Epoch [22], Train Loss : [0.37238] Val Loss : [0.39151] Val acc : [0.82045],Time : 1m 36s
# Epoch [23], Step [5], Train Loss : [0.34000] Train acc : [0.81250]
# Epoch [23], Step [10], Train Loss : [0.41550] Train acc : [0.75000]
# Epoch [23], Step [15], Train Loss : [0.27680] Train acc : [0.87500]
# Epoch [23], Step [20], Train Loss : [0.25980] Train acc : [0.93750]
# Epoch [23], Step [25], Train Loss : [0.50650] Train acc : [0.62500]
# Epoch [23], Step [30], Train Loss : [0.40920] Train acc : [0.75000]
# Epoch [23], Step [35], Train Loss : [0.39310] Train acc : [0.81250]
# Epoch [23], Step [40], Train Loss : [0.22860] Train acc : [1.00000]
# Epoch [23], Step [45], Train Loss : [0.40200] Train acc : [0.75000]
# Epoch [23], Step [50], Train Loss : [0.36750] Train acc : [0.81250]
# Epoch [23], Step [55], Train Loss : [0.26600] Train acc : [0.93750]
# Epoch [23], Step [60], Train Loss : [0.25070] Train acc : [0.87500]
# Epoch [23], Step [65], Train Loss : [0.29430] Train acc : [0.87500]
# Epoch [23], Step [70], Train Loss : [0.40660] Train acc : [0.81250]
# Epoch [23], Step [75], Train Loss : [0.27980] Train acc : [0.87500]
# Epoch [23], Step [80], Train Loss : [0.24350] Train acc : [0.93750]
# Epoch [23], Step [85], Train Loss : [0.28070] Train acc : [0.93750]
# Epoch [23], Train Loss : [0.36253] Val Loss : [0.39195] Val acc : [0.84034],Time : 1m 35s
# save_best_pth EPOCH 23
# Epoch [24], Step [5], Train Loss : [0.48210] Train acc : [0.81250]
# Epoch [24], Step [10], Train Loss : [0.27300] Train acc : [1.00000]
# Epoch [24], Step [15], Train Loss : [0.26480] Train acc : [0.93750]
# Epoch [24], Step [20], Train Loss : [0.53170] Train acc : [0.68750]
# Epoch [24], Step [25], Train Loss : [0.33090] Train acc : [0.93750]
# Epoch [24], Step [30], Train Loss : [0.34520] Train acc : [0.93750]
# Epoch [24], Step [35], Train Loss : [0.40530] Train acc : [0.75000]
# Epoch [24], Step [40], Train Loss : [0.28930] Train acc : [0.87500]
# Epoch [24], Step [45], Train Loss : [0.33100] Train acc : [0.87500]
# Epoch [24], Step [50], Train Loss : [0.35100] Train acc : [0.93750]
# Epoch [24], Step [55], Train Loss : [0.21010] Train acc : [1.00000]
# Epoch [24], Step [60], Train Loss : [0.28560] Train acc : [0.93750]
# Epoch [24], Step [65], Train Loss : [0.39050] Train acc : [0.75000]
# Epoch [24], Step [70], Train Loss : [0.23960] Train acc : [0.93750]
# Epoch [24], Step [75], Train Loss : [0.20950] Train acc : [1.00000]
# Epoch [24], Step [80], Train Loss : [0.30520] Train acc : [0.87500]
# Epoch [24], Step [85], Train Loss : [0.33790] Train acc : [0.81250]
# Epoch [24], Train Loss : [0.35912] Val Loss : [0.37689] Val acc : [0.84034],Time : 1m 36s
# Epoch [25], Step [5], Train Loss : [0.29560] Train acc : [0.93750]
# Epoch [25], Step [10], Train Loss : [0.29390] Train acc : [0.87500]
# Epoch [25], Step [15], Train Loss : [0.36380] Train acc : [0.81250]
# Epoch [25], Step [20], Train Loss : [0.28780] Train acc : [0.93750]
# Epoch [25], Step [25], Train Loss : [0.23340] Train acc : [0.93750]
# Epoch [25], Step [30], Train Loss : [0.28480] Train acc : [0.87500]
# Epoch [25], Step [35], Train Loss : [0.51640] Train acc : [0.68750]
# Epoch [25], Step [40], Train Loss : [0.33300] Train acc : [0.81250]
# Epoch [25], Step [45], Train Loss : [0.34990] Train acc : [0.81250]
# Epoch [25], Step [50], Train Loss : [0.50160] Train acc : [0.81250]
# Epoch [25], Step [55], Train Loss : [0.48940] Train acc : [0.75000]
# Epoch [25], Step [60], Train Loss : [0.36410] Train acc : [0.75000]
# Epoch [25], Step [65], Train Loss : [0.49110] Train acc : [0.81250]
# Epoch [25], Step [70], Train Loss : [0.40430] Train acc : [0.81250]
# Epoch [25], Step [75], Train Loss : [0.36870] Train acc : [0.87500]
# Epoch [25], Step [80], Train Loss : [0.35830] Train acc : [0.87500]
# Epoch [25], Step [85], Train Loss : [0.22360] Train acc : [0.93750]
# Epoch [25], Train Loss : [0.33847] Val Loss : [0.37487] Val acc : [0.83466],Time : 1m 35s
# Epoch [26], Step [5], Train Loss : [0.31050] Train acc : [0.87500]
# Epoch [26], Step [10], Train Loss : [0.31050] Train acc : [0.87500]
# Epoch [26], Step [15], Train Loss : [0.35200] Train acc : [0.87500]
# Epoch [26], Step [20], Train Loss : [0.27680] Train acc : [0.87500]
# Epoch [26], Step [25], Train Loss : [0.35380] Train acc : [0.81250]
# Epoch [26], Step [30], Train Loss : [0.51830] Train acc : [0.81250]
# Epoch [26], Step [35], Train Loss : [0.34450] Train acc : [0.87500]
# Epoch [26], Step [40], Train Loss : [0.38110] Train acc : [0.93750]
# Epoch [26], Step [45], Train Loss : [0.24530] Train acc : [0.93750]
# Epoch [26], Step [50], Train Loss : [0.26990] Train acc : [0.81250]
# Epoch [26], Step [55], Train Loss : [0.34750] Train acc : [0.81250]
# Epoch [26], Step [60], Train Loss : [0.25840] Train acc : [0.87500]
# Epoch [26], Step [65], Train Loss : [0.36250] Train acc : [0.81250]
# Epoch [26], Step [70], Train Loss : [0.19790] Train acc : [1.00000]
# Epoch [26], Step [75], Train Loss : [0.18730] Train acc : [0.93750]
# Epoch [26], Step [80], Train Loss : [0.21740] Train acc : [0.93750]
# Epoch [26], Step [85], Train Loss : [0.46600] Train acc : [0.75000]
# Epoch [26], Train Loss : [0.33030] Val Loss : [0.36692] Val acc : [0.84602],Time : 1m 35s
# save_best_pth EPOCH 26
# Epoch [27], Step [5], Train Loss : [0.32570] Train acc : [0.87500]
# Epoch [27], Step [10], Train Loss : [0.39070] Train acc : [0.75000]
# Epoch [27], Step [15], Train Loss : [0.27830] Train acc : [0.87500]
# Epoch [27], Step [20], Train Loss : [0.35140] Train acc : [0.87500]
# Epoch [27], Step [25], Train Loss : [0.31610] Train acc : [0.93750]
# Epoch [27], Step [30], Train Loss : [0.45940] Train acc : [0.81250]
# Epoch [27], Step [35], Train Loss : [0.41250] Train acc : [0.81250]
# Epoch [27], Step [40], Train Loss : [0.28590] Train acc : [0.93750]
# Epoch [27], Step [45], Train Loss : [0.39540] Train acc : [0.81250]
# Epoch [27], Step [50], Train Loss : [0.38500] Train acc : [0.75000]
# Epoch [27], Step [55], Train Loss : [0.34630] Train acc : [0.87500]
# Epoch [27], Step [60], Train Loss : [0.38260] Train acc : [0.75000]
# Epoch [27], Step [65], Train Loss : [0.19560] Train acc : [1.00000]
# Epoch [27], Step [70], Train Loss : [0.25310] Train acc : [0.93750]
# Epoch [27], Step [75], Train Loss : [0.53360] Train acc : [0.68750]
# Epoch [27], Step [80], Train Loss : [0.26700] Train acc : [0.93750]
# Epoch [27], Step [85], Train Loss : [0.26070] Train acc : [0.93750]
# Epoch [27], Train Loss : [0.32285] Val Loss : [0.37064] Val acc : [0.84034],Time : 1m 35s
# Epoch [28], Step [5], Train Loss : [0.37230] Train acc : [0.75000]
# Epoch [28], Step [10], Train Loss : [0.65880] Train acc : [0.56250]
# Epoch [28], Step [15], Train Loss : [0.36250] Train acc : [0.87500]
# Epoch [28], Step [20], Train Loss : [0.57530] Train acc : [0.62500]
# Epoch [28], Step [25], Train Loss : [0.35260] Train acc : [0.87500]
# Epoch [28], Step [30], Train Loss : [0.27060] Train acc : [0.87500]
# Epoch [28], Step [35], Train Loss : [0.21630] Train acc : [0.93750]
# Epoch [28], Step [40], Train Loss : [0.30850] Train acc : [0.87500]
# Epoch [28], Step [45], Train Loss : [0.20210] Train acc : [0.93750]
# Epoch [28], Step [50], Train Loss : [0.33440] Train acc : [0.87500]
# Epoch [28], Step [55], Train Loss : [0.46360] Train acc : [0.75000]
# Epoch [28], Step [60], Train Loss : [0.20800] Train acc : [1.00000]
# Epoch [28], Step [65], Train Loss : [0.26760] Train acc : [0.87500]
# Epoch [28], Step [70], Train Loss : [0.28480] Train acc : [0.87500]
# Epoch [28], Step [75], Train Loss : [0.36620] Train acc : [0.81250]
# Epoch [28], Step [80], Train Loss : [0.29850] Train acc : [0.81250]
# Epoch [28], Step [85], Train Loss : [0.21870] Train acc : [0.87500]
# Epoch [28], Train Loss : [0.32371] Val Loss : [0.35168] Val acc : [0.86591],Time : 1m 35s
# save_best_pth EPOCH 28
# Epoch [29], Step [5], Train Loss : [0.48300] Train acc : [0.75000]
# Epoch [29], Step [10], Train Loss : [0.24230] Train acc : [0.87500]
# Epoch [29], Step [15], Train Loss : [0.35460] Train acc : [0.81250]
# Epoch [29], Step [20], Train Loss : [0.29380] Train acc : [0.87500]
# Epoch [29], Step [25], Train Loss : [0.26870] Train acc : [0.93750]
# Epoch [29], Step [30], Train Loss : [0.36450] Train acc : [0.81250]
# Epoch [29], Step [35], Train Loss : [0.24860] Train acc : [0.87500]
# Epoch [29], Step [40], Train Loss : [0.35600] Train acc : [0.87500]
# Epoch [29], Step [45], Train Loss : [0.31410] Train acc : [0.81250]
# Epoch [29], Step [50], Train Loss : [0.36350] Train acc : [0.87500]
# Epoch [29], Step [55], Train Loss : [0.30940] Train acc : [0.81250]
# Epoch [29], Step [60], Train Loss : [0.34670] Train acc : [0.87500]
# Epoch [29], Step [65], Train Loss : [0.24120] Train acc : [1.00000]
# Epoch [29], Step [70], Train Loss : [0.26190] Train acc : [0.93750]
# Epoch [29], Step [75], Train Loss : [0.25040] Train acc : [0.93750]
# Epoch [29], Step [80], Train Loss : [0.23750] Train acc : [0.93750]
# Epoch [29], Step [85], Train Loss : [0.27820] Train acc : [0.87500]
# Epoch [29], Train Loss : [0.31485] Val Loss : [0.34886] Val acc : [0.85455],Time : 1m 36s
# Epoch [30], Step [5], Train Loss : [0.33380] Train acc : [0.93750]
# Epoch [30], Step [10], Train Loss : [0.21730] Train acc : [0.93750]
# Epoch [30], Step [15], Train Loss : [0.35980] Train acc : [0.87500]
# Epoch [30], Step [20], Train Loss : [0.20620] Train acc : [0.93750]
# Epoch [30], Step [25], Train Loss : [0.30000] Train acc : [0.87500]
# Epoch [30], Step [30], Train Loss : [0.43930] Train acc : [0.75000]
# Epoch [30], Step [35], Train Loss : [0.22010] Train acc : [0.93750]
# Epoch [30], Step [40], Train Loss : [0.22780] Train acc : [1.00000]
# Epoch [30], Step [45], Train Loss : [0.25320] Train acc : [0.87500]
# Epoch [30], Step [50], Train Loss : [0.38320] Train acc : [0.87500]
# Epoch [30], Step [55], Train Loss : [0.43440] Train acc : [0.75000]
# Epoch [30], Step [60], Train Loss : [0.54450] Train acc : [0.75000]
# Epoch [30], Step [65], Train Loss : [0.33930] Train acc : [0.93750]
# Epoch [30], Step [70], Train Loss : [0.19900] Train acc : [0.93750]
# Epoch [30], Step [75], Train Loss : [0.44470] Train acc : [0.75000]
# Epoch [30], Step [80], Train Loss : [0.32750] Train acc : [0.81250]
# Epoch [30], Step [85], Train Loss : [0.29320] Train acc : [0.87500]
# Epoch [30], Train Loss : [0.30141] Val Loss : [0.33516] Val acc : [0.86875],Time : 1m 35s
# save_best_pth EPOCH 30
# Epoch [31], Step [5], Train Loss : [0.18140] Train acc : [0.93750]
# Epoch [31], Step [10], Train Loss : [0.20920] Train acc : [0.93750]
# Epoch [31], Step [15], Train Loss : [0.25900] Train acc : [0.93750]
# Epoch [31], Step [20], Train Loss : [0.18780] Train acc : [0.93750]
# Epoch [31], Step [25], Train Loss : [0.34320] Train acc : [0.87500]
# Epoch [31], Step [30], Train Loss : [0.26870] Train acc : [1.00000]
# Epoch [31], Step [35], Train Loss : [0.33430] Train acc : [0.87500]
# Epoch [31], Step [40], Train Loss : [0.24910] Train acc : [0.93750]
# Epoch [31], Step [45], Train Loss : [0.18960] Train acc : [0.93750]
# Epoch [31], Step [50], Train Loss : [0.20710] Train acc : [1.00000]
# Epoch [31], Step [55], Train Loss : [0.22360] Train acc : [0.93750]
# Epoch [31], Step [60], Train Loss : [0.24950] Train acc : [0.93750]
# Epoch [31], Step [65], Train Loss : [0.21660] Train acc : [0.93750]
# Epoch [31], Step [70], Train Loss : [0.35050] Train acc : [0.81250]
# Epoch [31], Step [75], Train Loss : [0.27560] Train acc : [0.93750]
# Epoch [31], Step [80], Train Loss : [0.27480] Train acc : [0.87500]
# Epoch [31], Step [85], Train Loss : [0.22580] Train acc : [1.00000]
# Epoch [31], Train Loss : [0.28058] Val Loss : [0.32992] Val acc : [0.86023],Time : 1m 36s
# Epoch [32], Step [5], Train Loss : [0.20550] Train acc : [0.93750]
# Epoch [32], Step [10], Train Loss : [0.24730] Train acc : [1.00000]
# Epoch [32], Step [15], Train Loss : [0.10600] Train acc : [1.00000]
# Epoch [32], Step [20], Train Loss : [0.17180] Train acc : [1.00000]
# Epoch [32], Step [25], Train Loss : [0.19690] Train acc : [0.93750]
# Epoch [32], Step [30], Train Loss : [0.14610] Train acc : [0.93750]
# Epoch [32], Step [35], Train Loss : [0.17750] Train acc : [1.00000]
# Epoch [32], Step [40], Train Loss : [0.15290] Train acc : [1.00000]
# Epoch [32], Step [45], Train Loss : [0.17300] Train acc : [0.93750]
# Epoch [32], Step [50], Train Loss : [0.35650] Train acc : [0.87500]
# Epoch [32], Step [55], Train Loss : [0.30510] Train acc : [0.87500]
# Epoch [32], Step [60], Train Loss : [0.33530] Train acc : [0.93750]
# Epoch [32], Step [65], Train Loss : [0.29540] Train acc : [0.87500]
# Epoch [32], Step [70], Train Loss : [0.29310] Train acc : [0.87500]
# Epoch [32], Step [75], Train Loss : [0.49620] Train acc : [0.68750]
# Epoch [32], Step [80], Train Loss : [0.29120] Train acc : [0.81250]
# Epoch [32], Step [85], Train Loss : [0.25500] Train acc : [0.93750]
# Epoch [32], Train Loss : [0.27470] Val Loss : [0.33167] Val acc : [0.86875],Time : 1m 36s
# Epoch [33], Step [5], Train Loss : [0.28680] Train acc : [0.93750]
# Epoch [33], Step [10], Train Loss : [0.18150] Train acc : [1.00000]
# Epoch [33], Step [15], Train Loss : [0.20020] Train acc : [1.00000]
# Epoch [33], Step [20], Train Loss : [0.24150] Train acc : [0.87500]
# Epoch [33], Step [25], Train Loss : [0.76540] Train acc : [0.62500]
# Epoch [33], Step [30], Train Loss : [0.23210] Train acc : [0.93750]
# Epoch [33], Step [35], Train Loss : [0.42120] Train acc : [0.75000]
# Epoch [33], Step [40], Train Loss : [0.31710] Train acc : [0.81250]
# Epoch [33], Step [45], Train Loss : [0.22750] Train acc : [0.93750]
# Epoch [33], Step [50], Train Loss : [0.38490] Train acc : [0.81250]
# Epoch [33], Step [55], Train Loss : [0.29860] Train acc : [0.87500]
# Epoch [33], Step [60], Train Loss : [0.30090] Train acc : [0.87500]
# Epoch [33], Step [65], Train Loss : [0.36680] Train acc : [0.87500]
# Epoch [33], Step [70], Train Loss : [0.27850] Train acc : [0.87500]
# Epoch [33], Step [75], Train Loss : [0.38860] Train acc : [0.87500]
# Epoch [33], Step [80], Train Loss : [0.30420] Train acc : [0.87500]
# Epoch [33], Step [85], Train Loss : [0.30980] Train acc : [0.87500]
# Epoch [33], Train Loss : [0.28172] Val Loss : [0.31828] Val acc : [0.87159],Time : 1m 35s
# save_best_pth EPOCH 33
# Epoch [34], Step [5], Train Loss : [0.36460] Train acc : [0.75000]
# Epoch [34], Step [10], Train Loss : [0.16110] Train acc : [0.93750]
# Epoch [34], Step [15], Train Loss : [0.32440] Train acc : [0.87500]
# Epoch [34], Step [20], Train Loss : [0.28800] Train acc : [0.93750]
# Epoch [34], Step [25], Train Loss : [0.15060] Train acc : [1.00000]
# Epoch [34], Step [30], Train Loss : [0.27220] Train acc : [0.93750]
# Epoch [34], Step [35], Train Loss : [0.24130] Train acc : [0.81250]
# Epoch [34], Step [40], Train Loss : [0.24710] Train acc : [0.87500]
# Epoch [34], Step [45], Train Loss : [0.20320] Train acc : [0.87500]
# Epoch [34], Step [50], Train Loss : [0.20160] Train acc : [1.00000]
# Epoch [34], Step [55], Train Loss : [0.19200] Train acc : [0.93750]
# Epoch [34], Step [60], Train Loss : [0.27170] Train acc : [0.87500]
# Epoch [34], Step [65], Train Loss : [0.20220] Train acc : [0.93750]
# Epoch [34], Step [70], Train Loss : [0.22830] Train acc : [0.87500]
# Epoch [34], Step [75], Train Loss : [0.28260] Train acc : [0.93750]
# Epoch [34], Step [80], Train Loss : [0.13450] Train acc : [1.00000]
# Epoch [34], Step [85], Train Loss : [0.22110] Train acc : [0.87500]
# Epoch [34], Train Loss : [0.27375] Val Loss : [0.31569] Val acc : [0.87159],Time : 1m 37s
# Epoch [35], Step [5], Train Loss : [0.18600] Train acc : [1.00000]
# Epoch [35], Step [10], Train Loss : [0.26290] Train acc : [0.87500]
# Epoch [35], Step [15], Train Loss : [0.20860] Train acc : [0.93750]
# Epoch [35], Step [20], Train Loss : [0.34880] Train acc : [0.81250]
# Epoch [35], Step [25], Train Loss : [0.32650] Train acc : [0.93750]
# Epoch [35], Step [30], Train Loss : [0.33530] Train acc : [0.81250]
# Epoch [35], Step [35], Train Loss : [0.21550] Train acc : [0.87500]
# Epoch [35], Step [40], Train Loss : [0.32300] Train acc : [0.81250]
# Epoch [35], Step [45], Train Loss : [0.21240] Train acc : [0.87500]
# Epoch [35], Step [50], Train Loss : [0.22970] Train acc : [0.87500]
# Epoch [35], Step [55], Train Loss : [0.19200] Train acc : [0.93750]
# Epoch [35], Step [60], Train Loss : [0.20220] Train acc : [0.93750]
# Epoch [35], Step [65], Train Loss : [0.21690] Train acc : [0.93750]
# Epoch [35], Step [70], Train Loss : [0.32980] Train acc : [0.87500]
# Epoch [35], Step [75], Train Loss : [0.29250] Train acc : [0.87500]
# Epoch [35], Step [80], Train Loss : [0.45380] Train acc : [0.75000]
# Epoch [35], Step [85], Train Loss : [0.17470] Train acc : [1.00000]
# Epoch [35], Train Loss : [0.26151] Val Loss : [0.30387] Val acc : [0.88580],Time : 1m 35s
# save_best_pth EPOCH 35
# Epoch [36], Step [5], Train Loss : [0.21870] Train acc : [0.93750]
# Epoch [36], Step [10], Train Loss : [0.27810] Train acc : [0.87500]
# Epoch [36], Step [15], Train Loss : [0.17190] Train acc : [1.00000]
# Epoch [36], Step [20], Train Loss : [0.42960] Train acc : [0.81250]
# Epoch [36], Step [25], Train Loss : [0.34340] Train acc : [0.87500]
# Epoch [36], Step [30], Train Loss : [0.22620] Train acc : [0.93750]
# Epoch [36], Step [35], Train Loss : [0.24050] Train acc : [0.87500]
# Epoch [36], Step [40], Train Loss : [0.52010] Train acc : [0.68750]
# Epoch [36], Step [45], Train Loss : [0.14090] Train acc : [1.00000]
# Epoch [36], Step [50], Train Loss : [0.13500] Train acc : [1.00000]
# Epoch [36], Step [55], Train Loss : [0.16570] Train acc : [0.93750]
# Epoch [36], Step [60], Train Loss : [0.35940] Train acc : [0.81250]
# Epoch [36], Step [65], Train Loss : [0.24040] Train acc : [0.93750]
# Epoch [36], Step [70], Train Loss : [0.26250] Train acc : [0.87500]
# Epoch [36], Step [75], Train Loss : [0.27930] Train acc : [0.87500]
# Epoch [36], Step [80], Train Loss : [0.20640] Train acc : [1.00000]
# Epoch [36], Step [85], Train Loss : [0.22000] Train acc : [0.93750]
# Epoch [36], Train Loss : [0.24343] Val Loss : [0.30332] Val acc : [0.88011],Time : 1m 35s
# Epoch [37], Step [5], Train Loss : [0.24980] Train acc : [0.93750]
# Epoch [37], Step [10], Train Loss : [0.13350] Train acc : [1.00000]
# Epoch [37], Step [15], Train Loss : [0.31470] Train acc : [0.87500]
# Epoch [37], Step [20], Train Loss : [0.70760] Train acc : [0.56250]
# Epoch [37], Step [25], Train Loss : [0.18670] Train acc : [0.93750]
# Epoch [37], Step [30], Train Loss : [0.28620] Train acc : [0.87500]
# Epoch [37], Step [35], Train Loss : [0.16660] Train acc : [0.93750]
# Epoch [37], Step [40], Train Loss : [0.39040] Train acc : [0.75000]
# Epoch [37], Step [45], Train Loss : [0.60610] Train acc : [0.68750]
# Epoch [37], Step [50], Train Loss : [0.20790] Train acc : [0.93750]
# Epoch [37], Step [55], Train Loss : [0.42680] Train acc : [0.87500]
# Epoch [37], Step [60], Train Loss : [0.09980] Train acc : [1.00000]
# Epoch [37], Step [65], Train Loss : [0.22780] Train acc : [1.00000]
# Epoch [37], Step [70], Train Loss : [0.20690] Train acc : [0.87500]
# Epoch [37], Step [75], Train Loss : [0.27070] Train acc : [0.93750]
# Epoch [37], Step [80], Train Loss : [0.15220] Train acc : [1.00000]
# Epoch [37], Step [85], Train Loss : [0.33770] Train acc : [0.81250]
# Epoch [37], Train Loss : [0.25114] Val Loss : [0.31749] Val acc : [0.86875],Time : 1m 36s
# Epoch [38], Step [5], Train Loss : [0.27700] Train acc : [0.93750]
# Epoch [38], Step [10], Train Loss : [0.48580] Train acc : [0.75000]
# Epoch [38], Step [15], Train Loss : [0.16670] Train acc : [1.00000]
# Epoch [38], Step [20], Train Loss : [0.26980] Train acc : [0.93750]
# Epoch [38], Step [25], Train Loss : [0.21370] Train acc : [0.93750]
# Epoch [38], Step [30], Train Loss : [0.19760] Train acc : [1.00000]
# Epoch [38], Step [35], Train Loss : [0.19810] Train acc : [0.93750]
# Epoch [38], Step [40], Train Loss : [0.25690] Train acc : [0.93750]
# Epoch [38], Step [45], Train Loss : [0.39950] Train acc : [0.75000]
# Epoch [38], Step [50], Train Loss : [0.20200] Train acc : [0.87500]
# Epoch [38], Step [55], Train Loss : [0.15090] Train acc : [1.00000]
# Epoch [38], Step [60], Train Loss : [0.23050] Train acc : [0.87500]
# Epoch [38], Step [65], Train Loss : [0.21610] Train acc : [0.87500]
# Epoch [38], Step [70], Train Loss : [0.25520] Train acc : [0.93750]
# Epoch [38], Step [75], Train Loss : [0.24220] Train acc : [0.93750]
# Epoch [38], Step [80], Train Loss : [0.27640] Train acc : [0.87500]
# Epoch [38], Step [85], Train Loss : [0.28140] Train acc : [0.87500]
# Epoch [38], Train Loss : [0.24336] Val Loss : [0.29094] Val acc : [0.88295],Time : 1m 36s
# Epoch [39], Step [5], Train Loss : [0.09560] Train acc : [1.00000]
# Epoch [39], Step [10], Train Loss : [0.11150] Train acc : [1.00000]
# Epoch [39], Step [15], Train Loss : [0.28100] Train acc : [0.87500]
# Epoch [39], Step [20], Train Loss : [0.17960] Train acc : [1.00000]
# Epoch [39], Step [25], Train Loss : [0.24220] Train acc : [0.93750]
# Epoch [39], Step [30], Train Loss : [0.29490] Train acc : [0.87500]
# Epoch [39], Step [35], Train Loss : [0.16160] Train acc : [1.00000]
# Epoch [39], Step [40], Train Loss : [0.16540] Train acc : [0.93750]
# Epoch [39], Step [45], Train Loss : [0.25350] Train acc : [0.87500]
# Epoch [39], Step [50], Train Loss : [0.26310] Train acc : [0.93750]
# Epoch [39], Step [55], Train Loss : [0.30180] Train acc : [0.93750]
# Epoch [39], Step [60], Train Loss : [0.22040] Train acc : [0.87500]
# Epoch [39], Step [65], Train Loss : [0.19750] Train acc : [0.93750]
# Epoch [39], Step [70], Train Loss : [0.38820] Train acc : [0.81250]
# Epoch [39], Step [75], Train Loss : [0.21700] Train acc : [0.93750]
# Epoch [39], Step [80], Train Loss : [0.23510] Train acc : [0.93750]
# Epoch [39], Step [85], Train Loss : [0.20230] Train acc : [0.87500]
# Epoch [39], Train Loss : [0.22294] Val Loss : [0.28885] Val acc : [0.88011],Time : 1m 37s
# Epoch [40], Step [5], Train Loss : [0.35830] Train acc : [0.87500]
# Epoch [40], Step [10], Train Loss : [0.24070] Train acc : [0.87500]
# Epoch [40], Step [15], Train Loss : [0.14020] Train acc : [1.00000]
# Epoch [40], Step [20], Train Loss : [0.24770] Train acc : [0.87500]
# Epoch [40], Step [25], Train Loss : [0.12850] Train acc : [1.00000]
# Epoch [40], Step [30], Train Loss : [0.29910] Train acc : [0.81250]
# Epoch [40], Step [35], Train Loss : [0.21820] Train acc : [0.87500]
# Epoch [40], Step [40], Train Loss : [0.18400] Train acc : [0.93750]
# Epoch [40], Step [45], Train Loss : [0.30200] Train acc : [0.87500]
# Epoch [40], Step [50], Train Loss : [0.15610] Train acc : [1.00000]
# Epoch [40], Step [55], Train Loss : [0.17630] Train acc : [0.93750]
# Epoch [40], Step [60], Train Loss : [0.30900] Train acc : [0.81250]
# Epoch [40], Step [65], Train Loss : [0.10040] Train acc : [1.00000]
# Epoch [40], Step [70], Train Loss : [0.13630] Train acc : [1.00000]
# Epoch [40], Step [75], Train Loss : [0.13740] Train acc : [0.93750]
# Epoch [40], Step [80], Train Loss : [0.33740] Train acc : [0.81250]
# Epoch [40], Step [85], Train Loss : [0.15730] Train acc : [1.00000]
# Epoch [40], Train Loss : [0.21487] Val Loss : [0.28954] Val acc : [0.88295],Time : 1m 35s
# Epoch [41], Step [5], Train Loss : [0.26520] Train acc : [0.93750]
# Epoch [41], Step [10], Train Loss : [0.21480] Train acc : [0.93750]
# Epoch [41], Step [15], Train Loss : [0.14440] Train acc : [0.93750]
# Epoch [41], Step [20], Train Loss : [0.21520] Train acc : [0.93750]
# Epoch [41], Step [25], Train Loss : [0.19230] Train acc : [0.93750]
# Epoch [41], Step [30], Train Loss : [0.20120] Train acc : [1.00000]
# Epoch [41], Step [35], Train Loss : [0.20430] Train acc : [0.93750]
# Epoch [41], Step [40], Train Loss : [0.13790] Train acc : [0.93750]
# Epoch [41], Step [45], Train Loss : [0.16870] Train acc : [0.93750]
# Epoch [41], Step [50], Train Loss : [0.16280] Train acc : [0.93750]
# Epoch [41], Step [55], Train Loss : [0.24110] Train acc : [0.93750]
# Epoch [41], Step [60], Train Loss : [0.15720] Train acc : [0.93750]
# Epoch [41], Step [65], Train Loss : [0.19450] Train acc : [1.00000]
# Epoch [41], Step [70], Train Loss : [0.24100] Train acc : [0.93750]
# Epoch [41], Step [75], Train Loss : [0.27060] Train acc : [0.87500]
# Epoch [41], Step [80], Train Loss : [0.40720] Train acc : [0.81250]
# Epoch [41], Step [85], Train Loss : [0.23050] Train acc : [0.93750]
# Epoch [41], Train Loss : [0.21891] Val Loss : [0.27389] Val acc : [0.88011],Time : 1m 36s
# Epoch [42], Step [5], Train Loss : [0.26130] Train acc : [0.87500]
# Epoch [42], Step [10], Train Loss : [0.24940] Train acc : [0.81250]
# Epoch [42], Step [15], Train Loss : [0.11950] Train acc : [1.00000]
# Epoch [42], Step [20], Train Loss : [0.37000] Train acc : [0.81250]
# Epoch [42], Step [25], Train Loss : [0.14560] Train acc : [0.93750]
# Epoch [42], Step [30], Train Loss : [0.17320] Train acc : [0.93750]
# Epoch [42], Step [35], Train Loss : [0.09850] Train acc : [1.00000]
# Epoch [42], Step [40], Train Loss : [0.18320] Train acc : [0.93750]
# Epoch [42], Step [45], Train Loss : [0.15210] Train acc : [1.00000]
# Epoch [42], Step [50], Train Loss : [0.39250] Train acc : [0.87500]
# Epoch [42], Step [55], Train Loss : [0.12780] Train acc : [0.93750]
# Epoch [42], Step [60], Train Loss : [0.33350] Train acc : [0.87500]
# Epoch [42], Step [65], Train Loss : [0.15320] Train acc : [0.93750]
# Epoch [42], Step [70], Train Loss : [0.10560] Train acc : [0.93750]
# Epoch [42], Step [75], Train Loss : [0.33290] Train acc : [0.81250]
# Epoch [42], Step [80], Train Loss : [0.16010] Train acc : [1.00000]
# Epoch [42], Step [85], Train Loss : [0.18940] Train acc : [0.93750]
# Epoch [42], Train Loss : [0.20643] Val Loss : [0.27814] Val acc : [0.88011],Time : 1m 34s
# Epoch [43], Step [5], Train Loss : [0.20830] Train acc : [0.87500]
# Epoch [43], Step [10], Train Loss : [0.19900] Train acc : [0.93750]
# Epoch [43], Step [15], Train Loss : [0.07520] Train acc : [1.00000]
# Epoch [43], Step [20], Train Loss : [0.18800] Train acc : [0.93750]
# Epoch [43], Step [25], Train Loss : [0.16450] Train acc : [0.87500]
# Epoch [43], Step [30], Train Loss : [0.50390] Train acc : [0.81250]
# Epoch [43], Step [35], Train Loss : [0.08020] Train acc : [1.00000]
# Epoch [43], Step [40], Train Loss : [0.24620] Train acc : [0.87500]
# Epoch [43], Step [45], Train Loss : [0.18840] Train acc : [0.93750]
# Epoch [43], Step [50], Train Loss : [0.09880] Train acc : [1.00000]
# Epoch [43], Step [55], Train Loss : [0.09430] Train acc : [1.00000]
# Epoch [43], Step [60], Train Loss : [0.21610] Train acc : [0.87500]
# Epoch [43], Step [65], Train Loss : [0.34020] Train acc : [0.87500]
# Epoch [43], Step [70], Train Loss : [0.28340] Train acc : [0.87500]
# Epoch [43], Step [75], Train Loss : [0.20370] Train acc : [0.87500]
# Epoch [43], Step [80], Train Loss : [0.19580] Train acc : [0.93750]
# Epoch [43], Step [85], Train Loss : [0.22550] Train acc : [0.93750]
# Epoch [43], Train Loss : [0.20430] Val Loss : [0.26234] Val acc : [0.88864],Time : 1m 35s
# save_best_pth EPOCH 43
# Epoch [44], Step [5], Train Loss : [0.06650] Train acc : [1.00000]
# Epoch [44], Step [10], Train Loss : [0.26750] Train acc : [0.81250]
# Epoch [44], Step [15], Train Loss : [0.17620] Train acc : [0.93750]
# Epoch [44], Step [20], Train Loss : [0.19400] Train acc : [0.87500]
# Epoch [44], Step [25], Train Loss : [0.17290] Train acc : [0.93750]
# Epoch [44], Step [30], Train Loss : [0.22850] Train acc : [0.93750]
# Epoch [44], Step [35], Train Loss : [0.22390] Train acc : [0.87500]
# Epoch [44], Step [40], Train Loss : [0.19600] Train acc : [0.93750]
# Epoch [44], Step [45], Train Loss : [0.17190] Train acc : [0.87500]
# Epoch [44], Step [50], Train Loss : [0.23420] Train acc : [0.87500]
# Epoch [44], Step [55], Train Loss : [0.16710] Train acc : [0.93750]
# Epoch [44], Step [60], Train Loss : [0.38250] Train acc : [0.75000]
# Epoch [44], Step [65], Train Loss : [0.38280] Train acc : [0.87500]
# Epoch [44], Step [70], Train Loss : [0.24400] Train acc : [0.81250]
# Epoch [44], Step [75], Train Loss : [0.16440] Train acc : [0.93750]
# Epoch [44], Step [80], Train Loss : [0.12650] Train acc : [1.00000]
# Epoch [44], Step [85], Train Loss : [0.12400] Train acc : [1.00000]
# Epoch [44], Train Loss : [0.20116] Val Loss : [0.28269] Val acc : [0.88011],Time : 1m 36s
# Epoch [45], Step [5], Train Loss : [0.11310] Train acc : [0.93750]
# Epoch [45], Step [10], Train Loss : [0.18600] Train acc : [0.93750]
# Epoch [45], Step [15], Train Loss : [0.19380] Train acc : [0.93750]
# Epoch [45], Step [20], Train Loss : [0.08410] Train acc : [1.00000]
# Epoch [45], Step [25], Train Loss : [0.10770] Train acc : [1.00000]
# Epoch [45], Step [30], Train Loss : [0.16230] Train acc : [1.00000]
# Epoch [45], Step [35], Train Loss : [0.15740] Train acc : [0.93750]
# Epoch [45], Step [40], Train Loss : [0.19100] Train acc : [0.87500]
# Epoch [45], Step [45], Train Loss : [0.21200] Train acc : [0.93750]
# Epoch [45], Step [50], Train Loss : [0.16660] Train acc : [0.93750]
# Epoch [45], Step [55], Train Loss : [0.20670] Train acc : [0.87500]
# Epoch [45], Step [60], Train Loss : [0.15650] Train acc : [0.93750]
# Epoch [45], Step [65], Train Loss : [0.12940] Train acc : [1.00000]
# Epoch [45], Step [70], Train Loss : [0.18980] Train acc : [1.00000]
# Epoch [45], Step [75], Train Loss : [0.08990] Train acc : [1.00000]
# Epoch [45], Step [80], Train Loss : [0.17350] Train acc : [0.93750]
# Epoch [45], Step [85], Train Loss : [0.19070] Train acc : [0.93750]
# Epoch [45], Train Loss : [0.19685] Val Loss : [0.27823] Val acc : [0.88580],Time : 1m 36s
# Epoch [46], Step [5], Train Loss : [0.43610] Train acc : [0.75000]
# Epoch [46], Step [10], Train Loss : [0.09990] Train acc : [1.00000]
# Epoch [46], Step [15], Train Loss : [0.18030] Train acc : [0.93750]
# Epoch [46], Step [20], Train Loss : [0.19620] Train acc : [0.87500]
# Epoch [46], Step [25], Train Loss : [0.16660] Train acc : [0.93750]
# Epoch [46], Step [30], Train Loss : [0.10690] Train acc : [1.00000]
# Epoch [46], Step [35], Train Loss : [0.08700] Train acc : [1.00000]
# Epoch [46], Step [40], Train Loss : [0.22800] Train acc : [0.87500]
# Epoch [46], Step [45], Train Loss : [0.19340] Train acc : [0.93750]
# Epoch [46], Step [50], Train Loss : [0.53550] Train acc : [0.75000]
# Epoch [46], Step [55], Train Loss : [0.16180] Train acc : [0.93750]
# Epoch [46], Step [60], Train Loss : [0.35030] Train acc : [0.87500]
# Epoch [46], Step [65], Train Loss : [0.12730] Train acc : [1.00000]
# Epoch [46], Step [70], Train Loss : [0.19250] Train acc : [0.87500]
# Epoch [46], Step [75], Train Loss : [0.11410] Train acc : [1.00000]
# Epoch [46], Step [80], Train Loss : [0.24550] Train acc : [0.87500]
# Epoch [46], Step [85], Train Loss : [0.32940] Train acc : [0.93750]
# Epoch [46], Train Loss : [0.19255] Val Loss : [0.25791] Val acc : [0.88295],Time : 1m 35s
# Epoch [47], Step [5], Train Loss : [0.18410] Train acc : [0.93750]
# Epoch [47], Step [10], Train Loss : [0.17560] Train acc : [0.93750]
# Epoch [47], Step [15], Train Loss : [0.12090] Train acc : [1.00000]
# Epoch [47], Step [20], Train Loss : [0.24750] Train acc : [0.93750]
# Epoch [47], Step [25], Train Loss : [0.20750] Train acc : [0.93750]
# Epoch [47], Step [30], Train Loss : [0.27880] Train acc : [0.87500]
# Epoch [47], Step [35], Train Loss : [0.16580] Train acc : [0.93750]
# Epoch [47], Step [40], Train Loss : [0.20270] Train acc : [0.93750]
# Epoch [47], Step [45], Train Loss : [0.23820] Train acc : [0.93750]
# Epoch [47], Step [50], Train Loss : [0.18200] Train acc : [0.93750]
# Epoch [47], Step [55], Train Loss : [0.13730] Train acc : [1.00000]
# Epoch [47], Step [60], Train Loss : [0.11560] Train acc : [1.00000]
# Epoch [47], Step [65], Train Loss : [0.09700] Train acc : [1.00000]
# Epoch [47], Step [70], Train Loss : [0.17490] Train acc : [0.93750]
# Epoch [47], Step [75], Train Loss : [0.06980] Train acc : [1.00000]
# Epoch [47], Step [80], Train Loss : [0.11090] Train acc : [1.00000]
# Epoch [47], Step [85], Train Loss : [0.18640] Train acc : [0.93750]
# Epoch [47], Train Loss : [0.18134] Val Loss : [0.25342] Val acc : [0.88295],Time : 1m 37s
# Epoch [48], Step [5], Train Loss : [0.12210] Train acc : [0.93750]
# Epoch [48], Step [10], Train Loss : [0.18990] Train acc : [0.93750]
# Epoch [48], Step [15], Train Loss : [0.21020] Train acc : [0.93750]
# Epoch [48], Step [20], Train Loss : [0.09770] Train acc : [1.00000]
# Epoch [48], Step [25], Train Loss : [0.06450] Train acc : [1.00000]
# Epoch [48], Step [30], Train Loss : [0.14150] Train acc : [1.00000]
# Epoch [48], Step [35], Train Loss : [0.27160] Train acc : [0.87500]
# Epoch [48], Step [40], Train Loss : [0.12280] Train acc : [0.93750]
# Epoch [48], Step [45], Train Loss : [0.14560] Train acc : [1.00000]
# Epoch [48], Step [50], Train Loss : [0.26640] Train acc : [0.87500]
# Epoch [48], Step [55], Train Loss : [0.15290] Train acc : [0.93750]
# Epoch [48], Step [60], Train Loss : [0.27450] Train acc : [0.87500]
# Epoch [48], Step [65], Train Loss : [0.09340] Train acc : [1.00000]
# Epoch [48], Step [70], Train Loss : [0.14200] Train acc : [0.93750]
# Epoch [48], Step [75], Train Loss : [0.09920] Train acc : [1.00000]
# Epoch [48], Step [80], Train Loss : [0.16200] Train acc : [0.87500]
# Epoch [48], Step [85], Train Loss : [0.18860] Train acc : [0.87500]
# Epoch [48], Train Loss : [0.17709] Val Loss : [0.25071] Val acc : [0.88864],Time : 1m 35s
# Epoch [49], Step [5], Train Loss : [0.36220] Train acc : [0.87500]
# Epoch [49], Step [10], Train Loss : [0.14710] Train acc : [1.00000]
# Epoch [49], Step [15], Train Loss : [0.07910] Train acc : [1.00000]
# Epoch [49], Step [20], Train Loss : [0.08790] Train acc : [1.00000]
# Epoch [49], Step [25], Train Loss : [0.10320] Train acc : [1.00000]
# Epoch [49], Step [30], Train Loss : [0.26880] Train acc : [0.87500]
# Epoch [49], Step [35], Train Loss : [0.16030] Train acc : [1.00000]
# Epoch [49], Step [40], Train Loss : [0.44540] Train acc : [0.87500]
# Epoch [49], Step [45], Train Loss : [0.13030] Train acc : [0.93750]
# Epoch [49], Step [50], Train Loss : [0.14750] Train acc : [1.00000]
# Epoch [49], Step [55], Train Loss : [0.26850] Train acc : [0.81250]
# Epoch [49], Step [60], Train Loss : [0.15440] Train acc : [0.93750]
# Epoch [49], Step [65], Train Loss : [0.24120] Train acc : [0.93750]
# Epoch [49], Step [70], Train Loss : [0.20540] Train acc : [0.87500]
# Epoch [49], Step [75], Train Loss : [0.05050] Train acc : [1.00000]
# Epoch [49], Step [80], Train Loss : [0.30320] Train acc : [0.87500]
# Epoch [49], Step [85], Train Loss : [0.13480] Train acc : [0.93750]
# Epoch [49], Train Loss : [0.18410] Val Loss : [0.26423] Val acc : [0.88295],Time : 1m 36s
# Epoch [50], Step [5], Train Loss : [0.11550] Train acc : [1.00000]
# Epoch [50], Step [10], Train Loss : [0.32830] Train acc : [0.87500]
# Epoch [50], Step [15], Train Loss : [0.26880] Train acc : [0.81250]
# Epoch [50], Step [20], Train Loss : [0.10050] Train acc : [0.93750]
# Epoch [50], Step [25], Train Loss : [0.37250] Train acc : [0.87500]
# Epoch [50], Step [30], Train Loss : [0.21870] Train acc : [0.93750]
# Epoch [50], Step [35], Train Loss : [0.16110] Train acc : [0.93750]
# Epoch [50], Step [40], Train Loss : [0.29850] Train acc : [0.81250]
# Epoch [50], Step [45], Train Loss : [0.16870] Train acc : [0.93750]
# Epoch [50], Step [50], Train Loss : [0.18390] Train acc : [0.93750]
# Epoch [50], Step [55], Train Loss : [0.22490] Train acc : [0.93750]
# Epoch [50], Step [60], Train Loss : [0.16420] Train acc : [0.93750]
# Epoch [50], Step [65], Train Loss : [0.32120] Train acc : [0.87500]
# Epoch [50], Step [70], Train Loss : [0.15040] Train acc : [0.93750]
# Epoch [50], Step [75], Train Loss : [0.08030] Train acc : [1.00000]
# Epoch [50], Step [80], Train Loss : [0.17460] Train acc : [0.87500]
# Epoch [50], Step [85], Train Loss : [0.08940] Train acc : [0.93750]
# wandb: WARNING Symlinked 2 files into the W&B run directory, call wandb.save again to sync new files.
# Epoch [50], Train Loss : [0.17214] Val Loss : [0.24873] Val acc : [0.88295],Time : 1m 35s

# %%
# !nvidia-smi
# Out:
# Tue Jan 17 14:51:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.80.02    Driver Version: 450.80.02    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-PCIE...  Off  | 00000000:00:05.0 Off |                  Off |
# | N/A   42C    P0    37W / 250W |  32287MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
test_img_paths = "테스트 이미지 경로"

# %%
class CustomTestDataset(Dataset):
    def __init__(self, img_paths, labels, transforms=None):
        self.img_paths = img_paths
        self.transforms = transforms

    def __getitem__(self, index):
        img_path = self.img_paths

        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        
        if self.transforms is not None:
            image = self.transforms(image=image)['image']
        return image
    
    def __len__(self):
        return len(self.img_paths)

# %%
test_dataset = CustomTestDataset(test_img_paths, None, test_transform)
test_loader = DataLoader(test_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

# %%
def inference(model, img_path, device):
    model = BaseModel()
    model.load_state_dict(torch.load("/opt/ml/model_save_dir/best.pt", map_location=device))
    model = model.to(device)
    
    model_preds = []
    img_paths = []
    img_paths.append(img_path)
    
    model.eval()
    with torch.no_grad():
        for img in iter(test_loader):
            img = img.float().to(device)
            model_pred = model(img)
            model_preds.append(torch.round(model_pred).detach().cpu().numpy())
    
    print('Done.')
    return model_preds[0][0]

# %%
preds = inference(infer_model, test_img_paths, device)
print(preds)
# Out:
# Done.
# [1.]
