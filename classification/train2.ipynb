# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import os

import torch
from torch.utils.data import TensorDataset, DataLoader, Dataset, random_split
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.models as models
from torchvision import transforms
from torchvision.transforms import ToTensor, ToPILImage

import wandb

# %%
wandb.init(
    project="Final Project", 
    entity="aitech4_cv3",
    name='classification_resnet50',
    config = {
        "lr" : 0.0001,
        "epoch" : 50,
        "batch_size" : 8,
    }
    )

config = wandb.config
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jinnyeong (aitech4_cv3). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.9
# Run data is saved locally in <code>/opt/ml/classification/wandb/run-20230115_092735-60141am0</code>
# Syncing run <strong><a href="https://wandb.ai/aitech4_cv3/Final%20Project/runs/60141am0" target="_blank">classification_resnet50</a></strong> to <a href="https://wandb.ai/aitech4_cv3/Final%20Project" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#  View project at <a href="https://wandb.ai/aitech4_cv3/Final%20Project" target="_blank">https://wandb.ai/aitech4_cv3/Final%20Project</a>
#  View run at <a href="https://wandb.ai/aitech4_cv3/Final%20Project/runs/60141am0" target="_blank">https://wandb.ai/aitech4_cv3/Final%20Project/runs/60141am0</a>

# %%
trans = transforms.Compose([
    transforms.Resize((720,1280)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])

# %%
train_path = '/opt/ml/classification/input/train'
train_set = torchvision.datasets.ImageFolder(root=train_path, transform=trans)

valid_path = '/opt/ml/classification/input/valid'
valid_set = torchvision.datasets.ImageFolder(root=valid_path, transform=trans)

test_path = '/opt/ml/classification/input/test'
test_set = torchvision.datasets.ImageFolder(root=test_path, transform=trans)

# %%
train_set.__getitem__(200)
# Out:
# (tensor([[[-0.1765, -0.1922, -0.1608,  ..., -0.2941, -0.2941, -0.2941],
#           [-0.1294, -0.1451, -0.1529,  ..., -0.2941, -0.2941, -0.2941],
#           [-0.1059, -0.1216, -0.1373,  ..., -0.2941, -0.2941, -0.2941],
#           ...,
#           [-0.7569, -0.7647, -0.7647,  ..., -0.7804, -0.7725, -0.7882],
#           [-0.7725, -0.7725, -0.7647,  ..., -0.7490, -0.7490, -0.7647],
#           [-0.7725, -0.7725, -0.7725,  ..., -0.7569, -0.7725, -0.7882]],
#
#          [[-0.1922, -0.2000, -0.1686,  ..., -0.7882, -0.7882, -0.7882],
#           [-0.1137, -0.1216, -0.1373,  ..., -0.7882, -0.7882, -0.7882],
#           [-0.0431, -0.0588, -0.0824,  ..., -0.7882, -0.7882, -0.7882],
#           ...,
#           [-0.6706, -0.6784, -0.6784,  ..., -0.7176, -0.7098, -0.7176],
#           [-0.6784, -0.6784, -0.6784,  ..., -0.6863, -0.6784, -0.6941],
#           [-0.6784, -0.6784, -0.6784,  ..., -0.6863, -0.7020, -0.7176]],
#
#          [[-0.3333, -0.3412, -0.3176,  ..., -0.8588, -0.8588, -0.8588],
#           [-0.2157, -0.2314, -0.2392,  ..., -0.8588, -0.8588, -0.8588],
#           [-0.0824, -0.0980, -0.1216,  ..., -0.8588, -0.8588, -0.8588],
#           ...,
#           [-0.6549, -0.6627, -0.6627,  ..., -0.6941, -0.6863, -0.6941],
#           [-0.6627, -0.6627, -0.6627,  ..., -0.6627, -0.6549, -0.6706],
#           [-0.6627, -0.6627, -0.6627,  ..., -0.6627, -0.6784, -0.7020]]]),
#  0)

# %%
train_set.classes
# Out:
# ['0', '1']

# %%
train_loader = DataLoader(
    train_set,
    batch_size=config.batch_size,
    shuffle=True,
    num_workers=4
)
valid_loader = DataLoader(
    valid_set,
    batch_size=config.batch_size,
    shuffle=True,
    num_workers=4
)
test_loader = DataLoader(
    test_set,
    batch_size=config.batch_size,
    shuffle=True,
    num_workers=4
)

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()
print(images.shape, images.type())
print(labels.shape, labels.type())
print(labels)
# Out:
# torch.Size([8, 3, 720, 1280]) torch.FloatTensor
# torch.Size([8]) torch.LongTensor
# tensor([0, 1, 0, 1, 0, 1, 1, 0])

# %%
class MyModel(nn.Module):
    def __init__(self, num_classes=2):
        super().__init__()

        self.backbone = models.resnet50(pretrained=True)
        self.classifier = nn.Linear(1000, num_classes)

    def forward(self, x):
        x = self.backbone(x)
        x = self.classifier(x)
        return x

# %%
def training_epoch(train_loader, network, loss_func, optimizer, epoch=config.epoch):
    train_losses = []
    train_correct = 0
    log_interval = 10

    for batch_idx, (inputs, label) in enumerate(train_loader):

        use_cuda = torch.cuda.is_available()
        device = torch.device("cuda" if use_cuda else "cpu")
        
        inputs = inputs.to(device)
        label = label.to(device)

        optimizer.zero_grad()

        # batch_size = inputs.size()[0]
        # inputs = inputs.view(-1,64) # model의 input size에 맞춰야 함
        
        outputs = network(inputs)

        loss = loss_func(outputs,label)
        train_losses.append(loss.item())

        pred = torch.max(outputs,1)[1] # max index 추출 // torch.argmax도 가능
        train_correct += pred.eq(label).sum() # 맞춘 갯수 추출

        loss.backward()

        optimizer.step()

        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'
            .format(epoch, batch_idx*len(label), len(train_loader.dataset), 100. * batch_idx / len(train_loader),
            loss.item()))

        

    return train_losses, train_correct

# %%
def valid_epoch(valid_loader, network, loss_func):
    correct = 0
    valid_losses = []

    with torch.no_grad():
        for batch_idx, (inputs, labels) in enumerate(valid_loader):

            use_cuda = torch.cuda.is_available()
            device = torch.device("cuda" if use_cuda else "cpu")

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            batch_size = inputs.size()[0]
            # inputs = inputs.view(-1,64)

            outputs = network(inputs)

            loss = loss_func(outputs, labels)
            valid_losses.append(loss.item())

            pred = torch.max(outputs,1)[1]
            correct += pred.eq(labels).sum()

        valid_accuracy = 100. * correct / len(valid_loader.dataset)

        print('Valid set: Accuracy: {}/{} ({:.0f}%)\n'
              .format(correct, len(valid_loader.dataset),100. * correct / len(valid_loader.dataset)))

        return valid_losses, valid_accuracy

# %%
def training(network, learning_rate = config.lr):

      best_accuracy = 0.0
      best_epoch = 0
      epoch = 50

      cls_loss = nn.CrossEntropyLoss()
      optimizer = optim.Adam(network.parameters(), lr=learning_rate)

      train_losses_per_epoch = []
      valid_losses_per_epoch = []

      train_accuracies = []
      valid_accuracies = []

      for epoches in range(epoch):

            network.train()

            train_losses, train_correct = training_epoch(train_loader, network, cls_loss, optimizer, epoches)

            average_loss = np.mean(train_losses)
            train_losses_per_epoch.append(average_loss)

            train_accuracy = 100. * train_correct / len(train_loader.dataset)
            train_accuracies.append(train_accuracy)

            print('\nTraining set: Accuracy: {}/{} ({:.0f}%)'
                  .format(train_correct, len(train_loader.dataset),100. * train_correct / len(train_loader.dataset)))

            network.eval()

            correct = 0
            
            with torch.no_grad():
                  valid_losses, valid_accuracy = valid_epoch(valid_loader, network, cls_loss)
            
                  valid_losses_per_epoch.append(np.mean(valid_losses))
                  valid_accuracies.append(valid_accuracy)

                  if valid_accuracy > best_accuracy:
                        best_accuracy = valid_accuracy

                        if epoches != 0:
                              before_path = '/opt/ml/classification/pth/best_epoch{}.pth'.format(best_epoch)
                              os.remove(before_path)

                        best_epoch = epoches

                        path = '/opt/ml/classification/pth/best_epoch{}.pth'.format(epoches)
                        torch.save(network.state_dict(), path)

                        print('save best.pth')

            if epoches == epoch:
                  path = '/opt/ml/classification/pth/latest.pth'
                  torch.save(network.state_dict(), path)
                  print('save latest.pth')
                  print('done')

            wandb.log({'train_acc':train_accuracy, 'val_acc':valid_accuracy})
      
      return train_losses_per_epoch, valid_losses_per_epoch, train_accuracies, valid_accuracies

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

network = MyModel().to(device)
model_res50 = training(network)
# Out:
# Train Epoch: 0 [0/800 (0%)]	Loss: 1.014529
# Train Epoch: 0 [80/800 (10%)]	Loss: 0.666609
# Train Epoch: 0 [160/800 (20%)]	Loss: 0.272643
# Train Epoch: 0 [240/800 (30%)]	Loss: 0.467650
# Train Epoch: 0 [320/800 (40%)]	Loss: 0.228057
# Train Epoch: 0 [400/800 (50%)]	Loss: 0.284327
# Train Epoch: 0 [480/800 (60%)]	Loss: 0.469987
# Train Epoch: 0 [560/800 (70%)]	Loss: 0.316821
# Train Epoch: 0 [640/800 (80%)]	Loss: 0.668304
# Train Epoch: 0 [720/800 (90%)]	Loss: 0.767242
#
# Training set: Accuracy: 610/800 (76%)
# Valid set: Accuracy: 85/100 (85%)
#
# save best.pth
# Train Epoch: 1 [0/800 (0%)]	Loss: 0.332150
# Train Epoch: 1 [80/800 (10%)]	Loss: 0.209632
# Train Epoch: 1 [160/800 (20%)]	Loss: 0.200642
# Train Epoch: 1 [240/800 (30%)]	Loss: 0.204539
# Train Epoch: 1 [320/800 (40%)]	Loss: 1.136284
# Train Epoch: 1 [400/800 (50%)]	Loss: 0.827948
# Train Epoch: 1 [480/800 (60%)]	Loss: 0.110589
# Train Epoch: 1 [560/800 (70%)]	Loss: 0.119816
# Train Epoch: 1 [640/800 (80%)]	Loss: 0.225209
# Train Epoch: 1 [720/800 (90%)]	Loss: 0.452507
#
# Training set: Accuracy: 688/800 (86%)
# Valid set: Accuracy: 83/100 (83%)
#
# Train Epoch: 2 [0/800 (0%)]	Loss: 0.220574
# Train Epoch: 2 [80/800 (10%)]	Loss: 0.105622
# Train Epoch: 2 [160/800 (20%)]	Loss: 0.186767
# Train Epoch: 2 [240/800 (30%)]	Loss: 0.093106
# Train Epoch: 2 [320/800 (40%)]	Loss: 0.338745
# Train Epoch: 2 [400/800 (50%)]	Loss: 0.208595
# Train Epoch: 2 [480/800 (60%)]	Loss: 0.387927
# Train Epoch: 2 [560/800 (70%)]	Loss: 0.282156
# Train Epoch: 2 [640/800 (80%)]	Loss: 0.343522
# Train Epoch: 2 [720/800 (90%)]	Loss: 0.050914
#
# Training set: Accuracy: 709/800 (89%)
# Valid set: Accuracy: 84/100 (84%)
#
# Train Epoch: 3 [0/800 (0%)]	Loss: 0.061969
# Train Epoch: 3 [80/800 (10%)]	Loss: 0.135180
# Train Epoch: 3 [160/800 (20%)]	Loss: 0.141021
# Train Epoch: 3 [240/800 (30%)]	Loss: 0.133314
# Train Epoch: 3 [320/800 (40%)]	Loss: 0.291875
# Train Epoch: 3 [400/800 (50%)]	Loss: 0.189889
# Train Epoch: 3 [480/800 (60%)]	Loss: 0.080861
# Train Epoch: 3 [560/800 (70%)]	Loss: 0.161660
# Train Epoch: 3 [640/800 (80%)]	Loss: 0.107214
# Train Epoch: 3 [720/800 (90%)]	Loss: 0.614448
#
# Training set: Accuracy: 751/800 (94%)
# Valid set: Accuracy: 82/100 (82%)
#
# Train Epoch: 4 [0/800 (0%)]	Loss: 0.029540
# Train Epoch: 4 [80/800 (10%)]	Loss: 0.127066
# Train Epoch: 4 [160/800 (20%)]	Loss: 0.030872
# Train Epoch: 4 [240/800 (30%)]	Loss: 0.105521
# Train Epoch: 4 [320/800 (40%)]	Loss: 0.211698
# Train Epoch: 4 [400/800 (50%)]	Loss: 0.067491
# Train Epoch: 4 [480/800 (60%)]	Loss: 1.134047
# Train Epoch: 4 [560/800 (70%)]	Loss: 0.028733
# Train Epoch: 4 [640/800 (80%)]	Loss: 0.013518
# Train Epoch: 4 [720/800 (90%)]	Loss: 0.023011
#
# Training set: Accuracy: 754/800 (94%)
# Valid set: Accuracy: 85/100 (85%)
#
# Train Epoch: 5 [0/800 (0%)]	Loss: 0.012868
# Train Epoch: 5 [80/800 (10%)]	Loss: 0.866811
# Train Epoch: 5 [160/800 (20%)]	Loss: 0.040470
# Train Epoch: 5 [240/800 (30%)]	Loss: 0.056697
# Train Epoch: 5 [320/800 (40%)]	Loss: 0.047327
# Train Epoch: 5 [400/800 (50%)]	Loss: 0.435474
# Train Epoch: 5 [480/800 (60%)]	Loss: 0.343936
# Train Epoch: 5 [560/800 (70%)]	Loss: 0.008829
# Train Epoch: 5 [640/800 (80%)]	Loss: 0.002467
# Train Epoch: 5 [720/800 (90%)]	Loss: 0.327090
#
# Training set: Accuracy: 748/800 (94%)
# Valid set: Accuracy: 86/100 (86%)
#
# save best.pth
# Train Epoch: 6 [0/800 (0%)]	Loss: 0.072282
# Train Epoch: 6 [80/800 (10%)]	Loss: 0.114842
# Train Epoch: 6 [160/800 (20%)]	Loss: 0.142710
# Train Epoch: 6 [240/800 (30%)]	Loss: 0.040800
# Train Epoch: 6 [320/800 (40%)]	Loss: 0.004926
# Train Epoch: 6 [400/800 (50%)]	Loss: 0.028439
# Train Epoch: 6 [480/800 (60%)]	Loss: 0.008699
# Train Epoch: 6 [560/800 (70%)]	Loss: 0.007761
# Train Epoch: 6 [640/800 (80%)]	Loss: 0.003923
# Train Epoch: 6 [720/800 (90%)]	Loss: 0.156242
#
# Training set: Accuracy: 767/800 (96%)
# Valid set: Accuracy: 83/100 (83%)
#
# Train Epoch: 7 [0/800 (0%)]	Loss: 0.029038
# Train Epoch: 7 [80/800 (10%)]	Loss: 0.081126
# Train Epoch: 7 [160/800 (20%)]	Loss: 0.456080
# Train Epoch: 7 [240/800 (30%)]	Loss: 0.176572
# Train Epoch: 7 [320/800 (40%)]	Loss: 0.119006
# Train Epoch: 7 [400/800 (50%)]	Loss: 0.015781
# Train Epoch: 7 [480/800 (60%)]	Loss: 0.019373
# Train Epoch: 7 [560/800 (70%)]	Loss: 0.012743
# Train Epoch: 7 [640/800 (80%)]	Loss: 0.212246
# Train Epoch: 7 [720/800 (90%)]	Loss: 0.040654
#
# Training set: Accuracy: 758/800 (95%)
# Valid set: Accuracy: 88/100 (88%)
#
# save best.pth
# Train Epoch: 8 [0/800 (0%)]	Loss: 0.036947
# Train Epoch: 8 [80/800 (10%)]	Loss: 0.020664
# Train Epoch: 8 [160/800 (20%)]	Loss: 0.075532
# Train Epoch: 8 [240/800 (30%)]	Loss: 0.012297
# Train Epoch: 8 [320/800 (40%)]	Loss: 0.028340
# Train Epoch: 8 [400/800 (50%)]	Loss: 0.076433
# Train Epoch: 8 [480/800 (60%)]	Loss: 0.032081
# Train Epoch: 8 [560/800 (70%)]	Loss: 0.038942
# Train Epoch: 8 [640/800 (80%)]	Loss: 0.008529
# Train Epoch: 8 [720/800 (90%)]	Loss: 0.001355
#
# Training set: Accuracy: 780/800 (98%)
# Valid set: Accuracy: 88/100 (88%)
#
# Train Epoch: 9 [0/800 (0%)]	Loss: 0.028445
# Train Epoch: 9 [80/800 (10%)]	Loss: 0.090420
# Train Epoch: 9 [160/800 (20%)]	Loss: 0.006002
# Train Epoch: 9 [240/800 (30%)]	Loss: 0.196743
# Train Epoch: 9 [320/800 (40%)]	Loss: 0.002465
# Train Epoch: 9 [400/800 (50%)]	Loss: 0.042775
# Train Epoch: 9 [480/800 (60%)]	Loss: 0.008589
# Train Epoch: 9 [560/800 (70%)]	Loss: 0.105136
# Train Epoch: 9 [640/800 (80%)]	Loss: 0.503765
# Train Epoch: 9 [720/800 (90%)]	Loss: 0.040214
#
# Training set: Accuracy: 782/800 (98%)
# Valid set: Accuracy: 89/100 (89%)
#
# save best.pth
# Train Epoch: 10 [0/800 (0%)]	Loss: 0.086764
# Train Epoch: 10 [80/800 (10%)]	Loss: 0.001849
# Train Epoch: 10 [160/800 (20%)]	Loss: 0.001034
# Train Epoch: 10 [240/800 (30%)]	Loss: 0.023316
# Train Epoch: 10 [320/800 (40%)]	Loss: 0.021303
# Train Epoch: 10 [400/800 (50%)]	Loss: 0.176735
# Train Epoch: 10 [480/800 (60%)]	Loss: 0.025966
# Train Epoch: 10 [560/800 (70%)]	Loss: 0.082014
# Train Epoch: 10 [640/800 (80%)]	Loss: 0.176967
# Train Epoch: 10 [720/800 (90%)]	Loss: 0.017612
#
# Training set: Accuracy: 780/800 (98%)
# Valid set: Accuracy: 86/100 (86%)
#
# Train Epoch: 11 [0/800 (0%)]	Loss: 0.023213
# Train Epoch: 11 [80/800 (10%)]	Loss: 0.004696
# Train Epoch: 11 [160/800 (20%)]	Loss: 0.000171
# Train Epoch: 11 [240/800 (30%)]	Loss: 0.000663
# Train Epoch: 11 [320/800 (40%)]	Loss: 0.001263
# Train Epoch: 11 [400/800 (50%)]	Loss: 0.019160
# Train Epoch: 11 [480/800 (60%)]	Loss: 0.005148
# Train Epoch: 11 [560/800 (70%)]	Loss: 0.302489
# Train Epoch: 11 [640/800 (80%)]	Loss: 0.705827
# Train Epoch: 11 [720/800 (90%)]	Loss: 0.372144
#
# Training set: Accuracy: 766/800 (96%)
# Valid set: Accuracy: 70/100 (70%)
#
# Train Epoch: 12 [0/800 (0%)]	Loss: 0.192819
# Train Epoch: 12 [80/800 (10%)]	Loss: 0.307620
# Train Epoch: 12 [160/800 (20%)]	Loss: 0.005022
# Train Epoch: 12 [240/800 (30%)]	Loss: 0.044863
# Train Epoch: 12 [320/800 (40%)]	Loss: 0.253254
# Train Epoch: 12 [400/800 (50%)]	Loss: 0.245954
# Train Epoch: 12 [480/800 (60%)]	Loss: 0.351447
# Train Epoch: 12 [560/800 (70%)]	Loss: 0.079440
# Train Epoch: 12 [640/800 (80%)]	Loss: 0.869914
# Train Epoch: 12 [720/800 (90%)]	Loss: 0.021759
#
# Training set: Accuracy: 768/800 (96%)
# Valid set: Accuracy: 83/100 (83%)
#
# Train Epoch: 13 [0/800 (0%)]	Loss: 0.101010
# Train Epoch: 13 [80/800 (10%)]	Loss: 0.011947
# Train Epoch: 13 [160/800 (20%)]	Loss: 0.053216
# Train Epoch: 13 [240/800 (30%)]	Loss: 0.002917
# Train Epoch: 13 [320/800 (40%)]	Loss: 0.005633
# Train Epoch: 13 [400/800 (50%)]	Loss: 0.003610
# Train Epoch: 13 [480/800 (60%)]	Loss: 0.004261
# Train Epoch: 13 [560/800 (70%)]	Loss: 2.805395
# Train Epoch: 13 [640/800 (80%)]	Loss: 0.293717
# Train Epoch: 13 [720/800 (90%)]	Loss: 2.599304
#
# Training set: Accuracy: 761/800 (95%)
# Valid set: Accuracy: 81/100 (81%)
#
# Train Epoch: 14 [0/800 (0%)]	Loss: 0.680478
# Train Epoch: 14 [80/800 (10%)]	Loss: 0.150685
# Train Epoch: 14 [160/800 (20%)]	Loss: 0.238074
# Train Epoch: 14 [240/800 (30%)]	Loss: 0.086526
# Train Epoch: 14 [320/800 (40%)]	Loss: 0.049845
# Train Epoch: 14 [400/800 (50%)]	Loss: 0.072569
# Train Epoch: 14 [480/800 (60%)]	Loss: 0.019698
# Train Epoch: 14 [560/800 (70%)]	Loss: 0.028182
# Train Epoch: 14 [640/800 (80%)]	Loss: 0.006267
# Train Epoch: 14 [720/800 (90%)]	Loss: 0.240691
#
# Training set: Accuracy: 777/800 (97%)
# Valid set: Accuracy: 83/100 (83%)
#
# Train Epoch: 15 [0/800 (0%)]	Loss: 0.002809
# Train Epoch: 15 [80/800 (10%)]	Loss: 0.000636
# Train Epoch: 15 [160/800 (20%)]	Loss: 0.041816
# Train Epoch: 15 [240/800 (30%)]	Loss: 0.402846
# Train Epoch: 15 [320/800 (40%)]	Loss: 0.006482
# Train Epoch: 15 [400/800 (50%)]	Loss: 0.000952
# Train Epoch: 15 [480/800 (60%)]	Loss: 0.004606
# Train Epoch: 15 [560/800 (70%)]	Loss: 0.103925
# Train Epoch: 15 [640/800 (80%)]	Loss: 0.037220
# Train Epoch: 15 [720/800 (90%)]	Loss: 0.006635
#
# Training set: Accuracy: 792/800 (99%)
# Valid set: Accuracy: 81/100 (81%)
#
# Train Epoch: 16 [0/800 (0%)]	Loss: 0.100582
# Train Epoch: 16 [80/800 (10%)]	Loss: 0.004235
# Train Epoch: 16 [160/800 (20%)]	Loss: 0.002259
# Train Epoch: 16 [240/800 (30%)]	Loss: 0.002303
# Train Epoch: 16 [320/800 (40%)]	Loss: 0.001222
# Train Epoch: 16 [400/800 (50%)]	Loss: 0.004414
# Train Epoch: 16 [480/800 (60%)]	Loss: 0.118936
# Train Epoch: 16 [560/800 (70%)]	Loss: 0.023733
# Train Epoch: 16 [640/800 (80%)]	Loss: 0.673084
# Train Epoch: 16 [720/800 (90%)]	Loss: 0.013994
#
# Training set: Accuracy: 779/800 (97%)
# Valid set: Accuracy: 87/100 (87%)
#
# Train Epoch: 17 [0/800 (0%)]	Loss: 0.014526
# Train Epoch: 17 [80/800 (10%)]	Loss: 0.001017
# Train Epoch: 17 [160/800 (20%)]	Loss: 0.036206
# Train Epoch: 17 [240/800 (30%)]	Loss: 0.001007
# Train Epoch: 17 [320/800 (40%)]	Loss: 0.552105
# Train Epoch: 17 [400/800 (50%)]	Loss: 0.006793
# Train Epoch: 17 [480/800 (60%)]	Loss: 0.002832
# Train Epoch: 17 [560/800 (70%)]	Loss: 0.039902
# Train Epoch: 17 [640/800 (80%)]	Loss: 0.003988
# Train Epoch: 17 [720/800 (90%)]	Loss: 0.008402
#
# Training set: Accuracy: 789/800 (99%)
# Valid set: Accuracy: 83/100 (83%)
#
# Train Epoch: 18 [0/800 (0%)]	Loss: 0.000808
# Train Epoch: 18 [80/800 (10%)]	Loss: 0.002054
# Train Epoch: 18 [160/800 (20%)]	Loss: 0.002592
# Train Epoch: 18 [240/800 (30%)]	Loss: 0.005116
# Train Epoch: 18 [320/800 (40%)]	Loss: 0.026922
# Train Epoch: 18 [400/800 (50%)]	Loss: 0.108360
# Train Epoch: 18 [480/800 (60%)]	Loss: 0.008272
# Train Epoch: 18 [560/800 (70%)]	Loss: 0.001230
# Train Epoch: 18 [640/800 (80%)]	Loss: 0.000828
# Train Epoch: 18 [720/800 (90%)]	Loss: 0.014595
#
# Training set: Accuracy: 788/800 (98%)
# Valid set: Accuracy: 87/100 (87%)
#
# Train Epoch: 19 [0/800 (0%)]	Loss: 0.007305
# Train Epoch: 19 [80/800 (10%)]	Loss: 0.000403
# Train Epoch: 19 [160/800 (20%)]	Loss: 0.002944
# Train Epoch: 19 [240/800 (30%)]	Loss: 0.000717
# Train Epoch: 19 [320/800 (40%)]	Loss: 0.002021
# Train Epoch: 19 [400/800 (50%)]	Loss: 0.003062
# Train Epoch: 19 [480/800 (60%)]	Loss: 0.031304
# Train Epoch: 19 [560/800 (70%)]	Loss: 0.001010
# Train Epoch: 19 [640/800 (80%)]	Loss: 0.000754
# Train Epoch: 19 [720/800 (90%)]	Loss: 0.000315
#
# Training set: Accuracy: 800/800 (100%)
# Valid set: Accuracy: 86/100 (86%)
#
# Train Epoch: 20 [0/800 (0%)]	Loss: 0.000461
# Train Epoch: 20 [80/800 (10%)]	Loss: 0.001416
# Train Epoch: 20 [160/800 (20%)]	Loss: 0.000373
# Train Epoch: 20 [240/800 (30%)]	Loss: 0.002845
# Train Epoch: 20 [320/800 (40%)]	Loss: 0.000067
# Train Epoch: 20 [400/800 (50%)]	Loss: 0.000240
# Train Epoch: 20 [480/800 (60%)]	Loss: 0.004740
# Train Epoch: 20 [560/800 (70%)]	Loss: 0.480427
# Train Epoch: 20 [640/800 (80%)]	Loss: 0.001444
# Train Epoch: 20 [720/800 (90%)]	Loss: 0.029670
#
# Training set: Accuracy: 792/800 (99%)
# Valid set: Accuracy: 81/100 (81%)
#
# Train Epoch: 21 [0/800 (0%)]	Loss: 0.009598
# Train Epoch: 21 [80/800 (10%)]	Loss: 0.689458
# Train Epoch: 21 [160/800 (20%)]	Loss: 0.234972
# Train Epoch: 21 [240/800 (30%)]	Loss: 0.375637
# Train Epoch: 21 [320/800 (40%)]	Loss: 0.026124
# Train Epoch: 21 [400/800 (50%)]	Loss: 0.030746
# Train Epoch: 21 [480/800 (60%)]	Loss: 0.003810
# Train Epoch: 21 [560/800 (70%)]	Loss: 0.017329
# Train Epoch: 21 [640/800 (80%)]	Loss: 0.001616
# Train Epoch: 21 [720/800 (90%)]	Loss: 0.015725
#
# Training set: Accuracy: 766/800 (96%)
# Valid set: Accuracy: 87/100 (87%)
#
# Train Epoch: 22 [0/800 (0%)]	Loss: 0.348027
# Train Epoch: 22 [80/800 (10%)]	Loss: 0.125686
# Train Epoch: 22 [160/800 (20%)]	Loss: 0.003924
# Train Epoch: 22 [240/800 (30%)]	Loss: 0.001036
# Train Epoch: 22 [320/800 (40%)]	Loss: 0.012284
# Train Epoch: 22 [400/800 (50%)]	Loss: 0.144864
# Train Epoch: 22 [480/800 (60%)]	Loss: 0.024005
# Train Epoch: 22 [560/800 (70%)]	Loss: 0.024396
# Train Epoch: 22 [640/800 (80%)]	Loss: 0.024450
# Train Epoch: 22 [720/800 (90%)]	Loss: 0.090380
#
# Training set: Accuracy: 781/800 (98%)
# Valid set: Accuracy: 80/100 (80%)
#
# Train Epoch: 23 [0/800 (0%)]	Loss: 0.008981
# Train Epoch: 23 [80/800 (10%)]	Loss: 0.031881
# Train Epoch: 23 [160/800 (20%)]	Loss: 0.010392
# Train Epoch: 23 [240/800 (30%)]	Loss: 0.006587
# Train Epoch: 23 [320/800 (40%)]	Loss: 0.004271
# Train Epoch: 23 [400/800 (50%)]	Loss: 0.021505
# Train Epoch: 23 [480/800 (60%)]	Loss: 0.007073
# Train Epoch: 23 [560/800 (70%)]	Loss: 0.000382
# Train Epoch: 23 [640/800 (80%)]	Loss: 0.079852
# Train Epoch: 23 [720/800 (90%)]	Loss: 0.008177
#
# Training set: Accuracy: 786/800 (98%)
# Valid set: Accuracy: 84/100 (84%)
#
# Train Epoch: 24 [0/800 (0%)]	Loss: 0.009089
# Train Epoch: 24 [80/800 (10%)]	Loss: 0.066303
# Train Epoch: 24 [160/800 (20%)]	Loss: 0.001316
# Train Epoch: 24 [240/800 (30%)]	Loss: 0.001628
# Train Epoch: 24 [320/800 (40%)]	Loss: 0.001063
# Train Epoch: 24 [400/800 (50%)]	Loss: 0.031488
# Train Epoch: 24 [480/800 (60%)]	Loss: 0.002265
# Train Epoch: 24 [560/800 (70%)]	Loss: 0.011704
# Train Epoch: 24 [640/800 (80%)]	Loss: 0.003990
# Train Epoch: 24 [720/800 (90%)]	Loss: 0.000500
#
# Training set: Accuracy: 796/800 (100%)
# Valid set: Accuracy: 85/100 (85%)
#
# Train Epoch: 25 [0/800 (0%)]	Loss: 0.000803
# Train Epoch: 25 [80/800 (10%)]	Loss: 0.002681
# Train Epoch: 25 [160/800 (20%)]	Loss: 0.002328
# Train Epoch: 25 [240/800 (30%)]	Loss: 0.001362
# Train Epoch: 25 [320/800 (40%)]	Loss: 0.000147
# Train Epoch: 25 [400/800 (50%)]	Loss: 0.000084
# Train Epoch: 25 [480/800 (60%)]	Loss: 0.000739
# Train Epoch: 25 [560/800 (70%)]	Loss: 0.002658
# Train Epoch: 25 [640/800 (80%)]	Loss: 0.001490
# Train Epoch: 25 [720/800 (90%)]	Loss: 0.001158
#
# Training set: Accuracy: 799/800 (100%)
# Valid set: Accuracy: 89/100 (89%)
#
# Train Epoch: 26 [0/800 (0%)]	Loss: 0.000044
# Train Epoch: 26 [80/800 (10%)]	Loss: 0.000080
# Train Epoch: 26 [160/800 (20%)]	Loss: 0.004588
# Train Epoch: 26 [240/800 (30%)]	Loss: 0.000463
# Train Epoch: 26 [320/800 (40%)]	Loss: 0.001386
# Train Epoch: 26 [400/800 (50%)]	Loss: 0.000579
# Train Epoch: 26 [480/800 (60%)]	Loss: 0.000317
# Train Epoch: 26 [560/800 (70%)]	Loss: 0.000228
# Train Epoch: 26 [640/800 (80%)]	Loss: 0.000034
# Train Epoch: 26 [720/800 (90%)]	Loss: 0.000153
#
# Training set: Accuracy: 799/800 (100%)
# Valid set: Accuracy: 84/100 (84%)
#
# Train Epoch: 27 [0/800 (0%)]	Loss: 0.000466
# Train Epoch: 27 [80/800 (10%)]	Loss: 0.000022
# Train Epoch: 27 [160/800 (20%)]	Loss: 0.000310
# Train Epoch: 27 [240/800 (30%)]	Loss: 0.002573
# Train Epoch: 27 [320/800 (40%)]	Loss: 0.004475
# Train Epoch: 27 [400/800 (50%)]	Loss: 0.012039
# Train Epoch: 27 [480/800 (60%)]	Loss: 0.035696
# Train Epoch: 27 [560/800 (70%)]	Loss: 0.055041
# Train Epoch: 27 [640/800 (80%)]	Loss: 0.002913
# Train Epoch: 27 [720/800 (90%)]	Loss: 0.015427
#
# Training set: Accuracy: 766/800 (96%)
# Valid set: Accuracy: 87/100 (87%)
#
# Train Epoch: 28 [0/800 (0%)]	Loss: 0.005206
# Train Epoch: 28 [80/800 (10%)]	Loss: 0.003616
# Train Epoch: 28 [160/800 (20%)]	Loss: 0.331830
# Train Epoch: 28 [240/800 (30%)]	Loss: 0.032674
# Train Epoch: 28 [320/800 (40%)]	Loss: 0.025897
# Train Epoch: 28 [400/800 (50%)]	Loss: 0.031330
# Train Epoch: 28 [480/800 (60%)]	Loss: 0.081293
# Train Epoch: 28 [560/800 (70%)]	Loss: 0.038315
# Train Epoch: 28 [640/800 (80%)]	Loss: 0.003126
# Train Epoch: 28 [720/800 (90%)]	Loss: 0.016437
#
# Training set: Accuracy: 777/800 (97%)
# Valid set: Accuracy: 85/100 (85%)
#
# Train Epoch: 29 [0/800 (0%)]	Loss: 0.010817
# Train Epoch: 29 [80/800 (10%)]	Loss: 0.002192
# Train Epoch: 29 [160/800 (20%)]	Loss: 0.001319
# Train Epoch: 29 [240/800 (30%)]	Loss: 0.020737
# Train Epoch: 29 [320/800 (40%)]	Loss: 0.000844
# Train Epoch: 29 [400/800 (50%)]	Loss: 0.355339
# Train Epoch: 29 [480/800 (60%)]	Loss: 0.011711
# Train Epoch: 29 [560/800 (70%)]	Loss: 0.001373
# Train Epoch: 29 [640/800 (80%)]	Loss: 0.002125
# Train Epoch: 29 [720/800 (90%)]	Loss: 0.034552
#
# Training set: Accuracy: 790/800 (99%)
# Valid set: Accuracy: 87/100 (87%)
#
# Train Epoch: 30 [0/800 (0%)]	Loss: 0.000513
# Train Epoch: 30 [80/800 (10%)]	Loss: 0.005592
# Train Epoch: 30 [160/800 (20%)]	Loss: 0.011902
# Train Epoch: 30 [240/800 (30%)]	Loss: 0.004738
# Train Epoch: 30 [320/800 (40%)]	Loss: 0.005664
# Train Epoch: 30 [400/800 (50%)]	Loss: 0.000458
# Train Epoch: 30 [480/800 (60%)]	Loss: 0.142206
# Train Epoch: 30 [560/800 (70%)]	Loss: 0.031337
# Train Epoch: 30 [640/800 (80%)]	Loss: 0.005591
# Train Epoch: 30 [720/800 (90%)]	Loss: 0.000566
#
# Training set: Accuracy: 788/800 (98%)
# Valid set: Accuracy: 88/100 (88%)
#
# Train Epoch: 31 [0/800 (0%)]	Loss: 0.000726
# Train Epoch: 31 [80/800 (10%)]	Loss: 0.000135
# Train Epoch: 31 [160/800 (20%)]	Loss: 0.001537
# Train Epoch: 31 [240/800 (30%)]	Loss: 0.008878
# Train Epoch: 31 [320/800 (40%)]	Loss: 0.019807
# Train Epoch: 31 [400/800 (50%)]	Loss: 0.000697
# Train Epoch: 31 [480/800 (60%)]	Loss: 0.002193
# Train Epoch: 31 [560/800 (70%)]	Loss: 0.057375
# Train Epoch: 31 [640/800 (80%)]	Loss: 0.003634
# Train Epoch: 31 [720/800 (90%)]	Loss: 0.000819
#
# Training set: Accuracy: 795/800 (99%)
# Valid set: Accuracy: 90/100 (90%)
#
# save best.pth
# Train Epoch: 32 [0/800 (0%)]	Loss: 0.004399
# Train Epoch: 32 [80/800 (10%)]	Loss: 0.001171
# Train Epoch: 32 [160/800 (20%)]	Loss: 0.003679
# Train Epoch: 32 [240/800 (30%)]	Loss: 0.010519
# Train Epoch: 32 [320/800 (40%)]	Loss: 0.000473
# Train Epoch: 32 [400/800 (50%)]	Loss: 0.411801
# Train Epoch: 32 [480/800 (60%)]	Loss: 0.000788
# Train Epoch: 32 [560/800 (70%)]	Loss: 0.000107
# Train Epoch: 32 [640/800 (80%)]	Loss: 0.015735
# Train Epoch: 32 [720/800 (90%)]	Loss: 0.004050
#
# Training set: Accuracy: 791/800 (99%)
# Valid set: Accuracy: 88/100 (88%)
#
# Train Epoch: 33 [0/800 (0%)]	Loss: 0.059027
# Train Epoch: 33 [80/800 (10%)]	Loss: 0.005954
# Train Epoch: 33 [160/800 (20%)]	Loss: 0.347095
# Train Epoch: 33 [240/800 (30%)]	Loss: 0.006299
# Train Epoch: 33 [320/800 (40%)]	Loss: 0.001812
# Train Epoch: 33 [400/800 (50%)]	Loss: 0.000153
# Train Epoch: 33 [480/800 (60%)]	Loss: 0.019798
# Train Epoch: 33 [560/800 (70%)]	Loss: 0.009723
# Train Epoch: 33 [640/800 (80%)]	Loss: 0.010721
# Train Epoch: 33 [720/800 (90%)]	Loss: 0.000610
#
# Training set: Accuracy: 783/800 (98%)
# Valid set: Accuracy: 86/100 (86%)
#
# Train Epoch: 34 [0/800 (0%)]	Loss: 0.062902
# Train Epoch: 34 [80/800 (10%)]	Loss: 0.004339
# Train Epoch: 34 [160/800 (20%)]	Loss: 0.015296
# Train Epoch: 34 [240/800 (30%)]	Loss: 0.005452
# Train Epoch: 34 [320/800 (40%)]	Loss: 0.006472
# Train Epoch: 34 [400/800 (50%)]	Loss: 0.003448
# Train Epoch: 34 [480/800 (60%)]	Loss: 0.000400
# Train Epoch: 34 [560/800 (70%)]	Loss: 0.000708
# Train Epoch: 34 [640/800 (80%)]	Loss: 0.018040
# Train Epoch: 34 [720/800 (90%)]	Loss: 0.541677
#
# Training set: Accuracy: 788/800 (98%)
# Valid set: Accuracy: 85/100 (85%)
#
# Train Epoch: 35 [0/800 (0%)]	Loss: 0.012208
# Train Epoch: 35 [80/800 (10%)]	Loss: 0.104101
# Train Epoch: 35 [160/800 (20%)]	Loss: 0.033029
# Train Epoch: 35 [240/800 (30%)]	Loss: 0.008591
# Train Epoch: 35 [320/800 (40%)]	Loss: 0.003374
# Train Epoch: 35 [400/800 (50%)]	Loss: 0.002051
# Train Epoch: 35 [480/800 (60%)]	Loss: 0.002118
# Train Epoch: 35 [560/800 (70%)]	Loss: 0.009627
# Train Epoch: 35 [640/800 (80%)]	Loss: 0.007138
# Train Epoch: 35 [720/800 (90%)]	Loss: 0.000277
#
# Training set: Accuracy: 790/800 (99%)
# Valid set: Accuracy: 88/100 (88%)
#
# Train Epoch: 36 [0/800 (0%)]	Loss: 0.000960
# Train Epoch: 36 [80/800 (10%)]	Loss: 0.000335
# Train Epoch: 36 [160/800 (20%)]	Loss: 0.000889
# Train Epoch: 36 [240/800 (30%)]	Loss: 0.002778
# Train Epoch: 36 [320/800 (40%)]	Loss: 0.000212
# Train Epoch: 36 [400/800 (50%)]	Loss: 0.006641
# Train Epoch: 36 [480/800 (60%)]	Loss: 0.000278
# Train Epoch: 36 [560/800 (70%)]	Loss: 0.020583
# Train Epoch: 36 [640/800 (80%)]	Loss: 0.001329
# Train Epoch: 36 [720/800 (90%)]	Loss: 0.004936
#
# Training set: Accuracy: 796/800 (100%)
# Valid set: Accuracy: 83/100 (83%)
#
# Train Epoch: 37 [0/800 (0%)]	Loss: 0.002216
# Train Epoch: 37 [80/800 (10%)]	Loss: 0.022966
# Train Epoch: 37 [160/800 (20%)]	Loss: 0.010418
# Train Epoch: 37 [240/800 (30%)]	Loss: 0.020629
# Train Epoch: 37 [320/800 (40%)]	Loss: 0.034856
# Train Epoch: 37 [400/800 (50%)]	Loss: 0.003162
# Train Epoch: 37 [480/800 (60%)]	Loss: 0.003401
# Train Epoch: 37 [560/800 (70%)]	Loss: 0.000143
# Train Epoch: 37 [640/800 (80%)]	Loss: 0.356691
# Train Epoch: 37 [720/800 (90%)]	Loss: 0.012812
#
# Training set: Accuracy: 789/800 (99%)
# Valid set: Accuracy: 83/100 (83%)
#
# Train Epoch: 38 [0/800 (0%)]	Loss: 0.090511
# Train Epoch: 38 [80/800 (10%)]	Loss: 0.005914
# Train Epoch: 38 [160/800 (20%)]	Loss: 0.004021
# Train Epoch: 38 [240/800 (30%)]	Loss: 0.000555
# Train Epoch: 38 [320/800 (40%)]	Loss: 0.002005
# Train Epoch: 38 [400/800 (50%)]	Loss: 0.054054
# Train Epoch: 38 [480/800 (60%)]	Loss: 0.000751
# Train Epoch: 38 [560/800 (70%)]	Loss: 0.015808
# Train Epoch: 38 [640/800 (80%)]	Loss: 0.008943
# Train Epoch: 38 [720/800 (90%)]	Loss: 0.000316
#
# Training set: Accuracy: 790/800 (99%)
# Valid set: Accuracy: 89/100 (89%)
#
# Train Epoch: 39 [0/800 (0%)]	Loss: 0.015056
# Train Epoch: 39 [80/800 (10%)]	Loss: 0.001333
# Train Epoch: 39 [160/800 (20%)]	Loss: 0.000094
# Train Epoch: 39 [240/800 (30%)]	Loss: 0.000947
# Train Epoch: 39 [320/800 (40%)]	Loss: 0.001642
# Train Epoch: 39 [400/800 (50%)]	Loss: 0.002092
# Train Epoch: 39 [480/800 (60%)]	Loss: 0.001205
# Train Epoch: 39 [560/800 (70%)]	Loss: 0.000578
# Train Epoch: 39 [640/800 (80%)]	Loss: 0.000509
# Train Epoch: 39 [720/800 (90%)]	Loss: 0.000365
#
# Training set: Accuracy: 800/800 (100%)
# Valid set: Accuracy: 86/100 (86%)
#
# Train Epoch: 40 [0/800 (0%)]	Loss: 0.004304
# Train Epoch: 40 [80/800 (10%)]	Loss: 0.001003
# Train Epoch: 40 [160/800 (20%)]	Loss: 0.000583
# Train Epoch: 40 [240/800 (30%)]	Loss: 0.000159
# Train Epoch: 40 [320/800 (40%)]	Loss: 0.000124
# Train Epoch: 40 [400/800 (50%)]	Loss: 0.000118
# Train Epoch: 40 [480/800 (60%)]	Loss: 0.000298
# Train Epoch: 40 [560/800 (70%)]	Loss: 0.001017
# Train Epoch: 40 [640/800 (80%)]	Loss: 0.000200
# Train Epoch: 40 [720/800 (90%)]	Loss: 0.001028
#
# Training set: Accuracy: 800/800 (100%)
# Valid set: Accuracy: 88/100 (88%)
#
# Train Epoch: 41 [0/800 (0%)]	Loss: 0.001066
# Train Epoch: 41 [80/800 (10%)]	Loss: 0.000132
# Train Epoch: 41 [160/800 (20%)]	Loss: 0.005678
# Train Epoch: 41 [240/800 (30%)]	Loss: 0.000244
# Train Epoch: 41 [320/800 (40%)]	Loss: 0.000252
# Train Epoch: 41 [400/800 (50%)]	Loss: 0.000046
# Train Epoch: 41 [480/800 (60%)]	Loss: 0.000337
# Train Epoch: 41 [560/800 (70%)]	Loss: 0.001329
# Train Epoch: 41 [640/800 (80%)]	Loss: 0.000059
# Train Epoch: 41 [720/800 (90%)]	Loss: 0.000624
#
# Training set: Accuracy: 799/800 (100%)
# Valid set: Accuracy: 87/100 (87%)
#
# Train Epoch: 42 [0/800 (0%)]	Loss: 0.002382
# Train Epoch: 42 [80/800 (10%)]	Loss: 0.000154
# Train Epoch: 42 [160/800 (20%)]	Loss: 0.002288
# Train Epoch: 42 [240/800 (30%)]	Loss: 0.002490
# Train Epoch: 42 [320/800 (40%)]	Loss: 0.000029
# Train Epoch: 42 [400/800 (50%)]	Loss: 0.003698
# Train Epoch: 42 [480/800 (60%)]	Loss: 0.000857
# Train Epoch: 42 [560/800 (70%)]	Loss: 0.000525
# Train Epoch: 42 [640/800 (80%)]	Loss: 0.000037
# Train Epoch: 42 [720/800 (90%)]	Loss: 0.000063
#
# Training set: Accuracy: 800/800 (100%)
# Valid set: Accuracy: 88/100 (88%)
#
# Train Epoch: 43 [0/800 (0%)]	Loss: 0.000371
# Train Epoch: 43 [80/800 (10%)]	Loss: 0.000196
# Train Epoch: 43 [160/800 (20%)]	Loss: 0.000154
# Train Epoch: 43 [240/800 (30%)]	Loss: 0.000129
# Train Epoch: 43 [320/800 (40%)]	Loss: 0.000907
# Train Epoch: 43 [400/800 (50%)]	Loss: 0.000123
# Train Epoch: 43 [480/800 (60%)]	Loss: 0.000073
# Train Epoch: 43 [560/800 (70%)]	Loss: 0.001082
# Train Epoch: 43 [640/800 (80%)]	Loss: 0.000010
# Train Epoch: 43 [720/800 (90%)]	Loss: 0.001280
#
# Training set: Accuracy: 800/800 (100%)
# Valid set: Accuracy: 88/100 (88%)
#
# Train Epoch: 44 [0/800 (0%)]	Loss: 0.000058
# Train Epoch: 44 [80/800 (10%)]	Loss: 0.004401
# Train Epoch: 44 [160/800 (20%)]	Loss: 0.000405
# Train Epoch: 44 [240/800 (30%)]	Loss: 0.000129
# Train Epoch: 44 [320/800 (40%)]	Loss: 0.000999
# Train Epoch: 44 [400/800 (50%)]	Loss: 0.000184
# Train Epoch: 44 [480/800 (60%)]	Loss: 0.000173
# Train Epoch: 44 [560/800 (70%)]	Loss: 0.000097
# Train Epoch: 44 [640/800 (80%)]	Loss: 0.000047
# Train Epoch: 44 [720/800 (90%)]	Loss: 0.000018
#
# Training set: Accuracy: 800/800 (100%)
# Valid set: Accuracy: 88/100 (88%)
#
# Train Epoch: 45 [0/800 (0%)]	Loss: 0.000125
# Train Epoch: 45 [80/800 (10%)]	Loss: 0.000268
# Train Epoch: 45 [160/800 (20%)]	Loss: 0.000050
# Train Epoch: 45 [240/800 (30%)]	Loss: 0.000017
# Train Epoch: 45 [320/800 (40%)]	Loss: 0.000023
# Train Epoch: 45 [400/800 (50%)]	Loss: 0.000078
# Train Epoch: 45 [480/800 (60%)]	Loss: 0.000013
# Train Epoch: 45 [560/800 (70%)]	Loss: 0.000104
# Train Epoch: 45 [640/800 (80%)]	Loss: 0.004067
# Train Epoch: 45 [720/800 (90%)]	Loss: 0.016143
#
# Training set: Accuracy: 795/800 (99%)
# Valid set: Accuracy: 81/100 (81%)
#
# Train Epoch: 46 [0/800 (0%)]	Loss: 1.518173
# Train Epoch: 46 [80/800 (10%)]	Loss: 0.035657
# Train Epoch: 46 [160/800 (20%)]	Loss: 0.194520
# Train Epoch: 46 [240/800 (30%)]	Loss: 0.009123
# Train Epoch: 46 [320/800 (40%)]	Loss: 0.032010
# Train Epoch: 46 [400/800 (50%)]	Loss: 0.243490
# Train Epoch: 46 [480/800 (60%)]	Loss: 0.031714
# Train Epoch: 46 [560/800 (70%)]	Loss: 0.013269
# Train Epoch: 46 [640/800 (80%)]	Loss: 0.025428
# Train Epoch: 46 [720/800 (90%)]	Loss: 0.174172
#
# Training set: Accuracy: 768/800 (96%)
# Valid set: Accuracy: 86/100 (86%)
#
# Train Epoch: 47 [0/800 (0%)]	Loss: 0.024059
# Train Epoch: 47 [80/800 (10%)]	Loss: 0.000549
# Train Epoch: 47 [160/800 (20%)]	Loss: 0.012508
# Train Epoch: 47 [240/800 (30%)]	Loss: 0.014377
# Train Epoch: 47 [320/800 (40%)]	Loss: 0.179669
# Train Epoch: 47 [400/800 (50%)]	Loss: 0.013333
# Train Epoch: 47 [480/800 (60%)]	Loss: 0.010112
# Train Epoch: 47 [560/800 (70%)]	Loss: 0.083271
# Train Epoch: 47 [640/800 (80%)]	Loss: 0.162030
# Train Epoch: 47 [720/800 (90%)]	Loss: 0.118644
#
# Training set: Accuracy: 782/800 (98%)
# Valid set: Accuracy: 83/100 (83%)
#
# Train Epoch: 48 [0/800 (0%)]	Loss: 0.030273
# Train Epoch: 48 [80/800 (10%)]	Loss: 0.013525
# Train Epoch: 48 [160/800 (20%)]	Loss: 0.003523
# Train Epoch: 48 [240/800 (30%)]	Loss: 0.067457
# Train Epoch: 48 [320/800 (40%)]	Loss: 0.028131
# Train Epoch: 48 [400/800 (50%)]	Loss: 0.009734
# Train Epoch: 48 [480/800 (60%)]	Loss: 0.002128
# Train Epoch: 48 [560/800 (70%)]	Loss: 0.063263
# Train Epoch: 48 [640/800 (80%)]	Loss: 0.047112
# Train Epoch: 48 [720/800 (90%)]	Loss: 0.068242
#
# Training set: Accuracy: 781/800 (98%)
# Valid set: Accuracy: 87/100 (87%)
#
# Train Epoch: 49 [0/800 (0%)]	Loss: 0.000468
# Train Epoch: 49 [80/800 (10%)]	Loss: 0.598739
# Train Epoch: 49 [160/800 (20%)]	Loss: 0.441801
# Train Epoch: 49 [240/800 (30%)]	Loss: 0.012300
# Train Epoch: 49 [320/800 (40%)]	Loss: 0.726696
# Train Epoch: 49 [400/800 (50%)]	Loss: 0.161880
# Train Epoch: 49 [480/800 (60%)]	Loss: 0.163969
# Train Epoch: 49 [560/800 (70%)]	Loss: 0.002036
# Train Epoch: 49 [640/800 (80%)]	Loss: 0.015473
# Train Epoch: 49 [720/800 (90%)]	Loss: 0.000379
#
# Training set: Accuracy: 786/800 (98%)
# Valid set: Accuracy: 84/100 (84%)

# %%
def test(network):
    best_path = '/opt/ml/classification/pth/best_epoch31.pth' # test마다 변경

    network.load_state_dict(torch.load(best_path))

    with torch.no_grad():
        for batch_idx, (inputs, labels) in enumerate(test_loader):
            
            use_cuda = torch.cuda.is_available()
            device = torch.device("cuda" if use_cuda else "cpu")

            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = network(inputs)

            pred = torch.max(outputs,1)[1]

            print('Prediction')
            print(pred)
            print('Label')
            print(labels)
            print()

            # if pred == 1:
            #     print('A pothole is detected')
            # else:
            #     print('A pothole is not detected')

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

test_model = MyModel().to(device)
resetnet50_test = test(test_model)
# Out:
# Prediction
# tensor([1, 0, 0, 0, 1, 1, 1, 1], device='cuda:0')
# Label
# tensor([1, 0, 0, 0, 0, 0, 1, 1], device='cuda:0')
#
# Prediction
# tensor([1, 1, 0, 0, 1, 0, 1, 0], device='cuda:0')
# Label
# tensor([1, 1, 0, 0, 1, 0, 0, 0], device='cuda:0')
#
# Prediction
# tensor([1, 0, 0, 0, 0, 1, 1, 1], device='cuda:0')
# Label
# tensor([1, 0, 0, 1, 1, 1, 1, 1], device='cuda:0')
#
# Prediction
# tensor([1, 1, 0, 0, 1, 0, 1, 0], device='cuda:0')
# Label
# tensor([1, 0, 0, 0, 1, 0, 1, 1], device='cuda:0')
#
# Prediction
# tensor([0, 1, 1, 0, 0, 1, 1, 0], device='cuda:0')
# Label
# tensor([1, 1, 1, 0, 1, 1, 1, 0], device='cuda:0')
#
# Prediction
# tensor([0, 1, 1, 1, 0, 1, 1, 0], device='cuda:0')
# Label
# tensor([0, 1, 1, 0, 0, 0, 1, 0], device='cuda:0')
#
# Prediction
# tensor([0, 1, 1, 1, 1, 0, 0, 0], device='cuda:0')
# Label
# tensor([0, 1, 1, 1, 0, 0, 0, 0], device='cuda:0')
#
# Prediction
# tensor([1, 0, 0, 0, 0, 0, 1, 1], device='cuda:0')
# Label
# tensor([1, 0, 0, 0, 0, 0, 1, 1], device='cuda:0')
#
# Prediction
# tensor([1, 1, 1, 0, 0, 1, 0, 0], device='cuda:0')
# Label
# tensor([0, 0, 1, 0, 1, 0, 0, 0], device='cuda:0')
#
# Prediction
# tensor([1, 1, 0, 1, 1, 1, 0, 0], device='cuda:0')
# Label
# tensor([1, 1, 0, 0, 1, 1, 0, 0], device='cuda:0')
#
# Prediction
# tensor([1, 1, 0, 1, 1, 0, 1, 1], device='cuda:0')
# Label
# tensor([1, 1, 0, 1, 1, 0, 1, 1], device='cuda:0')
#
# Prediction
# tensor([1, 0, 0, 0, 0, 1, 1, 0], device='cuda:0')
# Label
# tensor([0, 0, 0, 1, 0, 1, 1, 0], device='cuda:0')
#
# Prediction
# tensor([1, 1, 0, 1], device='cuda:0')
# Label
# tensor([1, 1, 1, 1], device='cuda:0')
